# %%
# Save the updated script with DOF prints added
# Import coerenti con il tuo stile
from pyomo.environ import ConcreteModel, SolverFactory, value
from idaes.core import FlowsheetBlock, MaterialBalanceType
from idaes.models.unit_models import Translator, Separator, Mixer
from idaes.models.properties.modular_properties.base.generic_property import GenericParameterBlock
from idaes.models_extra.power_generation.properties.natural_gas_PR import get_prop, get_rxn, EosType
import pyomo.environ as pyo
import idaes.core.util.scaling as iscale
import idaes.core.util.model_statistics as stattools
from idaes.core.util.initialization import propagate_state
import idaes.logger as idaeslog
from idaes.core.util.model_statistics import degrees_of_freedom
import idaes.models.unit_models as um
from pyomo.network import Arc
from idaes.models.properties.modular_properties.base.generic_reaction import GenericReactionParameterBlock
from idaes.core.util.model_statistics import (
    degrees_of_freedom, 
    report_statistics,
    activated_constraints_set,
    activated_equalities_set,
    unfixed_variables_set,
    fixed_variables_set,
    variables_set
)

# %%
# Logger silenzioso
idaeslog.getLogger("idaes.init").setLevel(idaeslog.ERROR)
idaeslog.getLogger("idaes.solve").setLevel(idaeslog.ERROR)

# Modello
m = ConcreteModel()
m.fs = FlowsheetBlock(dynamic=False)

# Proprietà
fuel_comps = {"H2": 0.99, "H2O": 0.01}
air_comps = {"O2": 0.21, "N2": 0.79}
reaction_comps = {"H2", "H2O", "O2"}

m.fs.fuel_props = GenericParameterBlock(**get_prop(fuel_comps, phases={"Vap"}, eos=EosType.PR))
m.fs.air_props = GenericParameterBlock(**get_prop(air_comps, phases={"Vap"}, eos=EosType.PR))
m.fs.reaction_props = GenericParameterBlock(**get_prop(reaction_comps, phases={"Vap"}, eos=EosType.PR))

def print_stream(unit, label, stream):
    separator = '=' * 60
    subsection = '-' * 60

    print(f"\n{separator}")
    print(f"{label:^60}")
    print(f"{separator}")

    print("\nSTREAM PROPERTIES:")
    print(f"{'Flow [mol/s]':<20}: {value(stream.flow_mol[0]):.6e}")
    print(f"{'Temperature [K]':<20}: {value(stream.temperature[0]):.2f}")
    print(f"{'Pressure [Pa]':<20}: {value(stream.pressure[0]):.2f}")

    print("\nMOLE FRACTIONS:")
    for t, c in stream.mole_frac_comp.keys():
        print(f"  x_{c:<10}: {value(stream.mole_frac_comp[t, c]):.6e}")

    print(f"\nDOF after {label}: {degrees_of_freedom(unit)}")

    print(f"\n{subsection}")
    print("MODEL STATISTICS REPORT:")
    print(subsection)
    report_statistics(unit)

    print(f"\n{subsection}")
    print("VARIABLES:")
    print(subsection)
    for i, v in enumerate(variables_set(unit)):
        print(f" {i+1} - {v}")

    print(f"\n{subsection}")
    print("ACTIVATED CONSTRAINTS:")
    print(subsection)
    for i, c in enumerate(activated_constraints_set(unit)):
        print(f" {i+1} - {c}")

    print(f"\n{subsection}")
    print("ACTIVATED EQUALITIES:")
    print(subsection)
    for i, eq in enumerate(activated_equalities_set(unit)):
        print(f" {i+1} - {eq}")

    print(f"\n{subsection}")
    print("UNFIXED VARIABLES:")
    print(subsection)
    for i, ufv in enumerate(unfixed_variables_set(unit)):
        print(f" {i+1} - {ufv}")

    print(f"\n{subsection}")
    print("FIXED VARIABLES:")
    print(subsection)
    for i, fv in enumerate(fixed_variables_set(unit)):
        print(f" {i+1} - {fv}")

    print(separator)
    print("\n")

# %%
T_fuel_in = 668.9 + 273.15  # = 942.05 K
T_fuel_out = 740.0 + 273.15  # = 1013.15 K
T_tot_in = 675.3 + 273.15  # = 948.45 K
T_air_in = 675.3 + 273.15  # = 948.45 K
T_air_out = 740.0 + 273.15  # = 1013.15 K
T_tot_out = 740.0 + 273.15  # = 1013.15 K

# If you want, you can also store the summed values directly:
T_fuel_in = 942.05
T_fuel_out = 1013.15
T_tot_in = 948.45
T_air_in = 948.45
T_air_out = 1013.15
T_tot_out = 1013.15

# %%
"""Delete translator_h2 if it already exists to avoid redefinition warning
if hasattr(m.fs, "translator_h2"):
    m.fs.del_component("translator_h2")"""
#Sara: add this to each unit to avoid warning error when running this cell multiple times OR re run the cells above.
"""Even if you’re sure it’s only defined once in your code, Jupyter notebooks keep the model alive across cells, so:
If you rerun a cell that redefines translator_h2, the warning will come back.
The fix (del_component()) is safe and correct, and helps make your notebook idempotent (safe to re-run cells in any order).
If the warning appears, use del_component() — even if you're sure there's only one definition in your code.
The warning is not about your code structure, it’s about the current state of the Python model object (m.fs) in memory."""
# Out:
# "Even if you’re sure it’s only defined once in your code, Jupyter notebooks keep the model alive across cells, so:\nIf you rerun a cell that redefines translator_h2, the warning will come back.\nThe fix (del_component()) is safe and correct, and helps make your notebook idempotent (safe to re-run cells in any order).\nIf the warning appears, use del_component() — even if you're sure there's only one definition in your code.\nThe warning is not about your code structure, it’s about the current state of the Python model object (m.fs) in memory."

# %%
# ----------------------------------------------------------------------------------------------------------------
# UNITÀ: Translator H2
# ----------------------------------------------------------------------------------------------------------------

m.fs.translator_h2 = Translator(
    inlet_property_package=m.fs.fuel_props,
    outlet_property_package=m.fs.reaction_props,
    outlet_state_defined=False,
)
m.fs.translator_h2.inlet.flow_mol[0].fix(0.075397) #Sara: change from 0.00015 kg/s to 0.075397 mol/s
m.fs.translator_h2.inlet.temperature[0].fix(942.05) # Sara: T_fuel_in changed based on excel file
m.fs.translator_h2.inlet.pressure[0].fix(101325)
m.fs.translator_h2.inlet.mole_frac_comp[:, "H2"].fix(0.99)
m.fs.translator_h2.inlet.mole_frac_comp[:, "H2O"].fix(0.01)

@m.fs.translator_h2.Constraint(m.fs.time)
def temp_eqn_h2(b, t): 
    return b.properties_out[t].temperature == b.properties_in[t].temperature

@m.fs.translator_h2.Constraint(m.fs.time)
def press_eqn_h2(b, t): 
    return b.properties_out[t].pressure == b.properties_in[t].pressure

@m.fs.translator_h2.Constraint(m.fs.time)
def flow_eqn_h2(b, t): 
    return b.properties_out[t].flow_mol == b.properties_in[t].flow_mol

@m.fs.translator_h2.Constraint(m.fs.time, list(m.fs.translator_h2.properties_in[0].mole_frac_comp.keys()))
def mole_frac_eqn_h2(b, t, j): 
    return b.properties_out[t].mole_frac_comp[j] == b.properties_in[t].mole_frac_comp[j]


# ----------------------------------------------------------------------------------------------------------------
# UNITÀ: Separator Air in o2_rich e o2_poor
# ----------------------------------------------------------------------------------------------------------------
m.fs.separator = Separator(
    property_package=m.fs.air_props,
    outlet_list=["o2_rich_strm", "o2_poor_strm"],
    split_basis=um.SplittingType.componentFlow,
)
m.fs.separator.inlet.flow_mol[0].fix(0.075397 * 10) #Sara: change from 0.00015 kg/s to 0.075397 mol/s
m.fs.separator.inlet.temperature[0].fix(948.45) #Sara: T_air_in = 948.45 K
m.fs.separator.inlet.pressure[0].fix(101325)
m.fs.separator.inlet.mole_frac_comp[0, "O2"].fix(0.21)
m.fs.separator.inlet.mole_frac_comp[0, "N2"].fix(0.79)
m.fs.separator.split_fraction[0, "o2_rich_strm", "O2"].fix(1.0)
m.fs.separator.split_fraction[0, "o2_rich_strm", "N2"].fix(0.0)


# ----------------------------------------------------------------------------------------------------------------
# UNITÀ: translator o2_rich da separator a reaction_props NON FUNZIONAAAAAAAAAAAAAAAAAA
# ----------------------------------------------------------------------------------------------------------------
m.fs.translator_o2 = Translator(
    inlet_property_package=m.fs.air_props,
    outlet_property_package=m.fs.reaction_props,
    outlet_state_defined=False,
)
m.fs.o2_to_translator = Arc(source=m.fs.separator.o2_rich_strm, destination=m.fs.translator_o2.inlet)
pyo.TransformationFactory("network.expand_arcs").apply_to(m)

# ── 1.  Kill N2 in the inlet (must be done *before* solver) ──────────────────
m.fs.translator_o2.inlet.mole_frac_comp[0, "N2"].fix(0.0)
#m.fs.translator_o2.inlet.mole_frac_comp[0, "O2"].fix(1.0)

#Sara: added temp and pressure. DOF from 4 tdown to 2 but does it make sense?
m.fs.translator_o2.inlet.temperature[0].fix(948.45)
m.fs.translator_o2.inlet.pressure[0].fix(101325)

m.fs.translator_o2.properties_out[0].temperature.fix(948.45)
m.fs.translator_o2.properties_out[0].pressure.fix(101325)
m.fs.separator.inlet.flow_mol[0].fix(1.583337e-01)
m.fs.separator.outlet.flow_mol[0].fix(1.583337e-01)
for t in m.fs.time:
    m.fs.translator_o2.properties_out[t].mole_frac_comp["O2"].fix(1.0)
    m.fs.translator_o2.properties_out[t].mole_frac_comp["H2"].fix(1e-19)
    m.fs.translator_o2.properties_out[t].mole_frac_comp["H2O"].fix(1e-19)

#Sara: dall'output sembra che non prenda in considerazione i constraint ftp
#sembra non conoscere le properties in e per questo non usa questi constraint.
@m.fs.translator_o2.Constraint(m.fs.time)
def temp_eqn_o2(b, t): 
    return b.properties_out[t].temperature == b.properties_in[t].temperature

@m.fs.translator_o2.Constraint(m.fs.time)
def press_eqn_o2(b, t): 
    return b.properties_out[t].pressure == b.properties_in[t].pressure

@m.fs.translator_o2.Constraint(m.fs.time)
def flow_eqn_o2(b, t): 
    return b.properties_out[t].flow_mol == b.properties_in[t].flow_mol


# ----------------------------------------------------------------------------------------------------------------
# UNITÀ: Mixer per H2 e O2 inlet
# ----------------------------------------------------------------------------------------------------------------
m.fs.mixer = um.Mixer(
    inlet_list=["fuel_strm","o2_rich_strm"],
    momentum_mixing_type=um.MomentumMixingType.none,
    property_package=m.fs.reaction_props,
)
m.fs.mix_h2 = Arc(source=m.fs.translator_h2.outlet, destination=m.fs.mixer.fuel_strm)
m.fs.mix_o2 = Arc(source=m.fs.translator_o2.outlet, destination=m.fs.mixer.o2_rich_strm)

pyo.TransformationFactory("network.expand_arcs").apply_to(m)

@m.fs.mixer.Constraint(m.fs.time)
def pressure_eqn(b, t):
    return b.mixed_state[t].pressure == b.o2_rich_strm_state[t].pressure


# ----------------------------------------------------------------------------------------------------------------
# UNITÀ: Stochiometric Reactor
# ----------------------------------------------------------------------------------------------------------------
m.fs.rxn_props = GenericReactionParameterBlock(**get_rxn(m.fs.reaction_props, {"h2_cmb"}))
m.fs.reactor = um.StoichiometricReactor(
    property_package=m.fs.reaction_props,
    reaction_package=m.fs.rxn_props,
    has_pressure_change=False,
    has_heat_transfer=True,
)

m.fs.mix_to_reactor = Arc(source=m.fs.mixer.outlet, destination=m.fs.reactor.inlet)
pyo.TransformationFactory("network.expand_arcs").apply_to(m)


# ----------------------------------------------------------------------------------------------------------------
# UNITÀ: Separator water and O2
# ----------------------------------------------------------------------------------------------------------------
m.fs.reactor_separator = Separator(
    property_package=m.fs.reaction_props,
    outlet_list=['water_strm', 'o2_strm'],
    split_basis=um.SplittingType.componentFlow,
)
m.fs.react_to_sep = Arc(source=m.fs.reactor.outlet, destination=m.fs.reactor_separator.inlet)
pyo.TransformationFactory("network.expand_arcs").apply_to(m)

for j in ["H2", "H2O"]:
    m.fs.reactor_separator.split_fraction[0, "water_strm", j].fix(1.0)
m.fs.reactor_separator.split_fraction[0, "o2_strm", "O2"].fix(1.0)


# ----------------------------------------------------------------------------------------------------------------
# UNITÀ: Translator for H2O e H2 stream
# ----------------------------------------------------------------------------------------------------------------
m.fs.translator_h2_out = Translator(
    inlet_property_package=m.fs.reaction_props,
    outlet_property_package=m.fs.fuel_props,
    outlet_state_defined=False,
)

# Connessione dallo stream "water_strm" del separatore
m.fs.water_to_translator = Arc(
    source=m.fs.reactor_separator.water_strm,
    destination=m.fs.translator_h2_out.inlet
)

pyo.TransformationFactory("network.expand_arcs").apply_to(m)

# Constraint FTP standard (totale)
@m.fs.translator_h2_out.Constraint(m.fs.time)
def flow_eqn_h2_out(b, t):
    return b.properties_out[t].flow_mol == b.properties_in[t].flow_mol

@m.fs.translator_h2_out.Constraint(m.fs.time)
def temp_eqn_h2_out(b, t):
    return b.properties_out[t].temperature == b.properties_in[t].temperature

@m.fs.translator_h2_out.Constraint(m.fs.time)
def press_eqn_h2_out(b, t):
    return b.properties_out[t].pressure == b.properties_in[t].pressure

# Componenti comuni
comps_out = set(m.fs.translator_h2_out.properties_out[0].mole_frac_comp.keys())
comps_out.remove("H2")
# SOLO constraint flussi molari individuali per componenti comuni
@m.fs.translator_h2_out.Constraint(m.fs.time, comps_out)
def component_flow_eqn_h2_out(b, t, j):
    return (
                b.properties_out[t].mole_frac_comp[j]
                == b.properties_in[t].mole_frac_comp[j]
            )

#Sara: 
# ----------------------------------------------------------------------------------------------------------------
# UNITÀ: Translator for O2 stream out of the reactor (non reacted)
# ----------------------------------------------------------------------------------------------------------------
m.fs.translator_o2_out = Translator(
    inlet_property_package=m.fs.reaction_props,
    outlet_property_package=m.fs.air_props,
    outlet_state_defined=False,
)

# Connessione dallo stream "o2_rich_strm" del separatore
m.fs.air_to_translator = Arc(                   #called air_to_translator because o2_to_translator is already used
    source=m.fs.reactor_separator.o2_strm,
    destination=m.fs.translator_o2_out.inlet
)

pyo.TransformationFactory("network.expand_arcs").apply_to(m)

# Constraint FTP standard (totale)
@m.fs.translator_o2_out.Constraint(m.fs.time)
def flow_eqn_o2_out(b, t):
    return b.properties_out[t].flow_mol == b.properties_in[t].flow_mol

@m.fs.translator_o2_out.Constraint(m.fs.time)
def temp_eqn_o2_out(b, t):
    return b.properties_out[t].temperature == b.properties_in[t].temperature

@m.fs.translator_o2_out.Constraint(m.fs.time)
def press_eqn_o2_out(b, t):
    return b.properties_out[t].pressure == b.properties_in[t].pressure


comps = set(m.fs.translator_o2_out.properties_out[0].mole_frac_comp.keys())
comps.remove("O2")

@m.fs.translator_o2_out.Constraint(m.fs.time, comps)
def mole_frac_comp_eqn(b, t, c):
    return b.properties_out[t].mole_frac_comp[c] == 1e-19

# ----------------------------------------------------------------------------------------------------------------
# UNITÀ: Mixer for O2 stream out of the reactor (non reacted) and o2_poor stream from the inlet
# ----------------------------------------------------------------------------------------------------------------

m.fs.mixer2 = um.Mixer(
    inlet_list=["o2_strm","o2_poor_strm"],
    momentum_mixing_type=um.MomentumMixingType.none,
    property_package=m.fs.air_props,
)
m.fs.mix_o2_poor_strm = Arc(source=m.fs.separator.o2_poor_strm, destination=m.fs.mixer2.o2_poor_strm)
m.fs.mix_o2_strm = Arc(source=m.fs.translator_o2_out.outlet, destination=m.fs.mixer2.o2_strm)

pyo.TransformationFactory("network.expand_arcs").apply_to(m)

@m.fs.mixer2.Constraint(m.fs.time)
def pressure_eqn(b, t):
    return b.mixed_state[t].pressure == b.o2_poor_strm_state[t].pressure
# Out:
# WARNING (W1002): Setting Var
# 'fs.translator_o2.properties_in[0.0].mole_frac_comp[N2]' to a numeric value
# `0.0` outside the bounds (1e-20, 1.001).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002

# %%
m.fs.translator_h2.initialize()
propagate_state(m.fs.mix_h2)
print_stream(m.fs.translator_h2, "Translator H2 - Inlet", m.fs.translator_h2.inlet)
print_stream(m.fs.translator_h2, "Translator H2 - Outlet", m.fs.translator_h2.outlet)



m.fs.separator.initialize()
propagate_state(m.fs.o2_to_translator)
print_stream(m.fs.separator, "Separator Air - Inlet", m.fs.separator.inlet)
print_stream(m.fs.separator, "Separator Air - O2 Rich", m.fs.separator.o2_rich_strm)
print_stream(m.fs.separator, "Separator Air - O2 Poor", m.fs.separator.o2_poor_strm)



m.fs.translator_o2.initialize()
propagate_state(m.fs.mix_o2)
print_stream(m.fs.translator_o2, "Translator O2 - Inlet", m.fs.translator_o2.inlet)
print_stream(m.fs.translator_o2, "Translator O2 - Outlet", m.fs.translator_o2.outlet)



m.fs.mixer.initialize()
propagate_state(m.fs.mix_to_reactor)
print_stream(m.fs.mixer, "Mixer - O2 Inlet", m.fs.mixer.o2_rich_strm)
print_stream(m.fs.mixer, "Mixer - H2 Inlet", m.fs.mixer.fuel_strm)
print_stream(m.fs.mixer, "Mixer - Mixed Outlet", m.fs.mixer.outlet)




m.fs.reactor.initialize()
propagate_state(m.fs.react_to_sep)
print_stream(m.fs.reactor, "Reactor - Inlet", m.fs.reactor.inlet)
print_stream(m.fs.reactor, "Reactor - Outlet", m.fs.reactor.outlet)




m.fs.reactor_separator.initialize()
propagate_state(m.fs.water_to_translator)
print_stream(m.fs.reactor_separator, "Separator - O2 Stream", m.fs.reactor_separator.o2_strm)
print_stream(m.fs.reactor_separator, "Separator - Water Stream", m.fs.reactor_separator.water_strm)

#Sara:

m.fs.translator_h2_out.initialize()
print_stream(m.fs.translator_h2_out, "Translator H2 out - Inlet", m.fs.translator_h2_out.inlet)
print_stream(m.fs.translator_h2_out, "Translator H2 out - Outlet", m.fs.translator_h2_out.outlet)


m.fs.translator_o2_out.initialize()
propagate_state(m.fs.mix_o2_strm)
print_stream(m.fs.translator_o2_out, "Translator O2 out - Inlet", m.fs.translator_o2_out.inlet)
print_stream(m.fs.translator_o2_out, "Translator O2 out - Inlet", m.fs.translator_o2_out.outlet)

m.fs.mixer2.initialize()
print_stream(m.fs.mixer2, "Mixer - O2 stream Inlet", m.fs.mixer2.o2_strm)
print_stream(m.fs.mixer2, "Mixer - O2 poor stram Inlet", m.fs.mixer2.o2_poor_strm)
print_stream(m.fs.mixer2, "Mixer - Mixed Outlet", m.fs.mixer2.outlet)
# Out:
# ============================================================
#                    Translator H2 - Inlet
# ============================================================
#
# STREAM PROPERTIES:
# Flow [mol/s]        : 7.539700e-02
# Temperature [K]     : 942.05
# Pressure [Pa]       : 101325.00
#
# MOLE FRACTIONS:
#   x_H2        : 9.900000e-01
#   x_H2O       : 1.000000e-02
#
# DOF after Translator H2 - Inlet: 0
#
# ------------------------------------------------------------
# MODEL STATISTICS REPORT:
# ------------------------------------------------------------
#
# ========================================================================
# Model Statistics  -  fs.translator_h2
#
# Degrees of Freedom: 0
#
# Total No. Variables: 20
#     No. Fixed Variables: 5
#     No. Unused Variables: 0 (Fixed):0)
#     No. Variables only in Inequalities: 0 (Fixed: 0)
#
# Total No. Constraints: 15
#     No. Equality Constraints: 15 (Deactivated: 0)
#     No. Inequality Constraints: 0 (Deactivated: 0)
#
# No. Objectives: 0 (Deactivated: 0)
#
# No. Blocks: 3 (Deactivated: 0)
# No. Expressions: 65
# ========================================================================
#
#
# ------------------------------------------------------------
# VARIABLES:
# ------------------------------------------------------------
#  1 - fs.translator_h2.properties_in[0.0].flow_mol
#  2 - fs.translator_h2.properties_in[0.0].mole_frac_comp[H2]
#  3 - fs.translator_h2.properties_in[0.0].mole_frac_comp[H2O]
#  4 - fs.translator_h2.properties_in[0.0].temperature
#  5 - fs.translator_h2.properties_in[0.0].pressure
#  6 - fs.translator_h2.properties_out[0.0].flow_mol
#  7 - fs.translator_h2.properties_out[0.0].mole_frac_comp[H2]
#  8 - fs.translator_h2.properties_out[0.0].mole_frac_comp[H2O]
#  9 - fs.translator_h2.properties_out[0.0].mole_frac_comp[O2]
#  10 - fs.translator_h2.properties_out[0.0].temperature
#  11 - fs.translator_h2.properties_out[0.0].pressure
#  12 - fs.translator_h2.properties_in[0.0].flow_mol_phase[Vap]
#  13 - fs.translator_h2.properties_in[0.0].mole_frac_phase_comp[Vap,H2]
#  14 - fs.translator_h2.properties_in[0.0].mole_frac_phase_comp[Vap,H2O]
#  15 - fs.translator_h2.properties_in[0.0].phase_frac[Vap]
#  16 - fs.translator_h2.properties_out[0.0].flow_mol_phase[Vap]
#  17 - fs.translator_h2.properties_out[0.0].mole_frac_phase_comp[Vap,H2]
#  18 - fs.translator_h2.properties_out[0.0].mole_frac_phase_comp[Vap,H2O]
#  19 - fs.translator_h2.properties_out[0.0].mole_frac_phase_comp[Vap,O2]
#  20 - fs.translator_h2.properties_out[0.0].phase_frac[Vap]
#
# ------------------------------------------------------------
# ACTIVATED CONSTRAINTS:
# ------------------------------------------------------------
#  1 - fs.translator_h2.temp_eqn_h2[0.0]
#  2 - fs.translator_h2.press_eqn_h2[0.0]
#  3 - fs.translator_h2.flow_eqn_h2[0.0]
#  4 - fs.translator_h2.mole_frac_eqn_h2[0.0,H2]
#  5 - fs.translator_h2.mole_frac_eqn_h2[0.0,H2O]
#  6 - fs.translator_h2.properties_in[0.0].total_flow_balance
#  7 - fs.translator_h2.properties_in[0.0].component_flow_balances[H2]
#  8 - fs.translator_h2.properties_in[0.0].component_flow_balances[H2O]
#  9 - fs.translator_h2.properties_in[0.0].phase_fraction_constraint[Vap]
#  10 - fs.translator_h2.properties_out[0.0].sum_mole_frac_out
#  11 - fs.translator_h2.properties_out[0.0].total_flow_balance
#  12 - fs.translator_h2.properties_out[0.0].component_flow_balances[H2]
#  13 - fs.translator_h2.properties_out[0.0].component_flow_balances[H2O]
#  14 - fs.translator_h2.properties_out[0.0].component_flow_balances[O2]
#  15 - fs.translator_h2.properties_out[0.0].phase_fraction_constraint[Vap]
#
# ------------------------------------------------------------
# ACTIVATED EQUALITIES:
# ------------------------------------------------------------
#  1 - fs.translator_h2.temp_eqn_h2[0.0]
#  2 - fs.translator_h2.press_eqn_h2[0.0]
#  3 - fs.translator_h2.flow_eqn_h2[0.0]
#  4 - fs.translator_h2.mole_frac_eqn_h2[0.0,H2]
#  5 - fs.translator_h2.mole_frac_eqn_h2[0.0,H2O]
#  6 - fs.translator_h2.properties_in[0.0].total_flow_balance
#  7 - fs.translator_h2.properties_in[0.0].component_flow_balances[H2]
#  8 - fs.translator_h2.properties_in[0.0].component_flow_balances[H2O]
#  9 - fs.translator_h2.properties_in[0.0].phase_fraction_constraint[Vap]
#  10 - fs.translator_h2.properties_out[0.0].sum_mole_frac_out
#  11 - fs.translator_h2.properties_out[0.0].total_flow_balance
#  12 - fs.translator_h2.properties_out[0.0].component_flow_balances[H2]
#  13 - fs.translator_h2.properties_out[0.0].component_flow_balances[H2O]
#  14 - fs.translator_h2.properties_out[0.0].component_flow_balances[O2]
#  15 - fs.translator_h2.properties_out[0.0].phase_fraction_constraint[Vap]
#
# ------------------------------------------------------------
# UNFIXED VARIABLES:
# ------------------------------------------------------------
#  1 - fs.translator_h2.properties_out[0.0].flow_mol
#  2 - fs.translator_h2.properties_out[0.0].mole_frac_comp[H2]
#  3 - fs.translator_h2.properties_out[0.0].mole_frac_comp[H2O]
#  4 - fs.translator_h2.properties_out[0.0].mole_frac_comp[O2]
#  5 - fs.translator_h2.properties_out[0.0].temperature
#  6 - fs.translator_h2.properties_out[0.0].pressure
#  7 - fs.translator_h2.properties_in[0.0].flow_mol_phase[Vap]
#  8 - fs.translator_h2.properties_in[0.0].mole_frac_phase_comp[Vap,H2]
#  9 - fs.translator_h2.properties_in[0.0].mole_frac_phase_comp[Vap,H2O]
#  10 - fs.translator_h2.properties_in[0.0].phase_frac[Vap]
#  11 - fs.translator_h2.properties_out[0.0].flow_mol_phase[Vap]
#  12 - fs.translator_h2.properties_out[0.0].mole_frac_phase_comp[Vap,H2]
#  13 - fs.translator_h2.properties_out[0.0].mole_frac_phase_comp[Vap,H2O]
#  14 - fs.translator_h2.properties_out[0.0].mole_frac_phase_comp[Vap,O2]
#  15 - fs.translator_h2.properties_out[0.0].phase_frac[Vap]
#
# ------------------------------------------------------------
# FIXED VARIABLES:
# ------------------------------------------------------------
#  1 - fs.translator_h2.properties_in[0.0].flow_mol
#  2 - fs.translator_h2.properties_in[0.0].mole_frac_comp[H2]
#  3 - fs.translator_h2.properties_in[0.0].mole_frac_comp[H2O]
#  4 - fs.translator_h2.properties_in[0.0].temperature
#  5 - fs.translator_h2.properties_in[0.0].pressure
# ============================================================
#
#
#
# ============================================================
#                    Translator H2 - Outlet
# ============================================================
#
# STREAM PROPERTIES:
# Flow [mol/s]        : 7.539700e-02
# Temperature [K]     : 942.05
# Pressure [Pa]       : 101325.00
#
# MOLE FRACTIONS:
#   x_H2        : 9.900000e-01
#   x_H2O       : 1.000000e-02
#   x_O2        : 6.890105e-17
#
# DOF after Translator H2 - Outlet: 0
#
# ------------------------------------------------------------
# MODEL STATISTICS REPORT:
# ------------------------------------------------------------
#
# ========================================================================
# Model Statistics  -  fs.translator_h2
#
# Degrees of Freedom: 0
#
# Total No. Variables: 20
#     No. Fixed Variables: 5
#     No. Unused Variables: 0 (Fixed):0)
#     No. Variables only in Inequalities: 0 (Fixed: 0)
#
# Total No. Constraints: 15
#     No. Equality Constraints: 15 (Deactivated: 0)
#     No. Inequality Constraints: 0 (Deactivated: 0)
#
# No. Objectives: 0 (Deactivated: 0)
#
# No. Blocks: 3 (Deactivated: 0)
# No. Expressions: 65
# ========================================================================
#
#
# ------------------------------------------------------------
# VARIABLES:
# ------------------------------------------------------------
#  1 - fs.translator_h2.properties_in[0.0].flow_mol
#  2 - fs.translator_h2.properties_in[0.0].mole_frac_comp[H2]
#  3 - fs.translator_h2.properties_in[0.0].mole_frac_comp[H2O]
#  4 - fs.translator_h2.properties_in[0.0].temperature
#  5 - fs.translator_h2.properties_in[0.0].pressure
#  6 - fs.translator_h2.properties_out[0.0].flow_mol
#  7 - fs.translator_h2.properties_out[0.0].mole_frac_comp[H2]
#  8 - fs.translator_h2.properties_out[0.0].mole_frac_comp[H2O]
#  9 - fs.translator_h2.properties_out[0.0].mole_frac_comp[O2]
#  10 - fs.translator_h2.properties_out[0.0].temperature
#  11 - fs.translator_h2.properties_out[0.0].pressure
#  12 - fs.translator_h2.properties_in[0.0].flow_mol_phase[Vap]
#  13 - fs.translator_h2.properties_in[0.0].mole_frac_phase_comp[Vap,H2]
#  14 - fs.translator_h2.properties_in[0.0].mole_frac_phase_comp[Vap,H2O]
#  15 - fs.translator_h2.properties_in[0.0].phase_frac[Vap]
#  16 - fs.translator_h2.properties_out[0.0].flow_mol_phase[Vap]
#  17 - fs.translator_h2.properties_out[0.0].mole_frac_phase_comp[Vap,H2]
#  18 - fs.translator_h2.properties_out[0.0].mole_frac_phase_comp[Vap,H2O]
#  19 - fs.translator_h2.properties_out[0.0].mole_frac_phase_comp[Vap,O2]
#  20 - fs.translator_h2.properties_out[0.0].phase_frac[Vap]
#
# ------------------------------------------------------------
# ACTIVATED CONSTRAINTS:
# ------------------------------------------------------------
#  1 - fs.translator_h2.temp_eqn_h2[0.0]
#  2 - fs.translator_h2.press_eqn_h2[0.0]
#  3 - fs.translator_h2.flow_eqn_h2[0.0]
#  4 - fs.translator_h2.mole_frac_eqn_h2[0.0,H2]
#  5 - fs.translator_h2.mole_frac_eqn_h2[0.0,H2O]
#  6 - fs.translator_h2.properties_in[0.0].total_flow_balance
#  7 - fs.translator_h2.properties_in[0.0].component_flow_balances[H2]
#  8 - fs.translator_h2.properties_in[0.0].component_flow_balances[H2O]
#  9 - fs.translator_h2.properties_in[0.0].phase_fraction_constraint[Vap]
#  10 - fs.translator_h2.properties_out[0.0].sum_mole_frac_out
#  11 - fs.translator_h2.properties_out[0.0].total_flow_balance
#  12 - fs.translator_h2.properties_out[0.0].component_flow_balances[H2]
#  13 - fs.translator_h2.properties_out[0.0].component_flow_balances[H2O]
#  14 - fs.translator_h2.properties_out[0.0].component_flow_balances[O2]
#  15 - fs.translator_h2.properties_out[0.0].phase_fraction_constraint[Vap]
#
# ------------------------------------------------------------
# ACTIVATED EQUALITIES:
# ------------------------------------------------------------
#  1 - fs.translator_h2.temp_eqn_h2[0.0]
#  2 - fs.translator_h2.press_eqn_h2[0.0]
#  3 - fs.translator_h2.flow_eqn_h2[0.0]
#  4 - fs.translator_h2.mole_frac_eqn_h2[0.0,H2]
#  5 - fs.translator_h2.mole_frac_eqn_h2[0.0,H2O]
#  6 - fs.translator_h2.properties_in[0.0].total_flow_balance
#  7 - fs.translator_h2.properties_in[0.0].component_flow_balances[H2]
#  8 - fs.translator_h2.properties_in[0.0].component_flow_balances[H2O]
#  9 - fs.translator_h2.properties_in[0.0].phase_fraction_constraint[Vap]
#  10 - fs.translator_h2.properties_out[0.0].sum_mole_frac_out
#  11 - fs.translator_h2.properties_out[0.0].total_flow_balance
#  12 - fs.translator_h2.properties_out[0.0].component_flow_balances[H2]
#  13 - fs.translator_h2.properties_out[0.0].component_flow_balances[H2O]
#  14 - fs.translator_h2.properties_out[0.0].component_flow_balances[O2]
#  15 - fs.translator_h2.properties_out[0.0].phase_fraction_constraint[Vap]
#
# ------------------------------------------------------------
# UNFIXED VARIABLES:
# ------------------------------------------------------------
#  1 - fs.translator_h2.properties_out[0.0].flow_mol
#  2 - fs.translator_h2.properties_out[0.0].mole_frac_comp[H2]
#  3 - fs.translator_h2.properties_out[0.0].mole_frac_comp[H2O]
#  4 - fs.translator_h2.properties_out[0.0].mole_frac_comp[O2]
#  5 - fs.translator_h2.properties_out[0.0].temperature
#  6 - fs.translator_h2.properties_out[0.0].pressure
#  7 - fs.translator_h2.properties_in[0.0].flow_mol_phase[Vap]
#  8 - fs.translator_h2.properties_in[0.0].mole_frac_phase_comp[Vap,H2]
#  9 - fs.translator_h2.properties_in[0.0].mole_frac_phase_comp[Vap,H2O]
#  10 - fs.translator_h2.properties_in[0.0].phase_frac[Vap]
#  11 - fs.translator_h2.properties_out[0.0].flow_mol_phase[Vap]
#  12 - fs.translator_h2.properties_out[0.0].mole_frac_phase_comp[Vap,H2]
#  13 - fs.translator_h2.properties_out[0.0].mole_frac_phase_comp[Vap,H2O]
#  14 - fs.translator_h2.properties_out[0.0].mole_frac_phase_comp[Vap,O2]
#  15 - fs.translator_h2.properties_out[0.0].phase_frac[Vap]
#
# ------------------------------------------------------------
# FIXED VARIABLES:
# ------------------------------------------------------------
#  1 - fs.translator_h2.properties_in[0.0].flow_mol
#  2 - fs.translator_h2.properties_in[0.0].mole_frac_comp[H2]
#  3 - fs.translator_h2.properties_in[0.0].mole_frac_comp[H2O]
#  4 - fs.translator_h2.properties_in[0.0].temperature
#  5 - fs.translator_h2.properties_in[0.0].pressure
# ============================================================
#
#
#
# ============================================================
#                    Separator Air - Inlet
# ============================================================
#
# STREAM PROPERTIES:
# Flow [mol/s]        : 1.583337e-01
# Temperature [K]     : 948.45
# Pressure [Pa]       : 101325.00
#
# MOLE FRACTIONS:
#   x_O2        : 2.100000e-01
#   x_N2        : 7.900000e-01
#
# DOF after Separator Air - Inlet: 0
#
# ------------------------------------------------------------
# MODEL STATISTICS REPORT:
# ------------------------------------------------------------
#
# ========================================================================
# Model Statistics  -  fs.separator
#
# Degrees of Freedom: 0
#
# Total No. Variables: 31
#     No. Fixed Variables: 7
#     No. Unused Variables: 0 (Fixed):0)
#     No. Variables only in Inequalities: 0 (Fixed: 0)
#
# Total No. Constraints: 24
#     No. Equality Constraints: 24 (Deactivated: 0)
#     No. Inequality Constraints: 0 (Deactivated: 0)
#
# No. Objectives: 0 (Deactivated: 0)
#
# No. Blocks: 4 (Deactivated: 0)
# No. Expressions: 78
# ========================================================================
#
#
# ------------------------------------------------------------
# VARIABLES:
# ------------------------------------------------------------
#  1 - fs.separator.mixed_state[0.0].flow_mol
#  2 - fs.separator.mixed_state[0.0].mole_frac_comp[O2]
#  3 - fs.separator.mixed_state[0.0].mole_frac_comp[N2]
#  4 - fs.separator.mixed_state[0.0].temperature
#  5 - fs.separator.mixed_state[0.0].pressure
#  6 - fs.separator.split_fraction[0.0,o2_rich_strm,O2]
#  7 - fs.separator.split_fraction[0.0,o2_rich_strm,N2]
#  8 - fs.separator.split_fraction[0.0,o2_poor_strm,O2]
#  9 - fs.separator.split_fraction[0.0,o2_poor_strm,N2]
#  10 - fs.separator.o2_rich_strm_state[0.0].flow_mol
#  11 - fs.separator.o2_rich_strm_state[0.0].mole_frac_comp[O2]
#  12 - fs.separator.o2_rich_strm_state[0.0].mole_frac_comp[N2]
#  13 - fs.separator.o2_rich_strm_state[0.0].temperature
#  14 - fs.separator.o2_rich_strm_state[0.0].pressure
#  15 - fs.separator.o2_poor_strm_state[0.0].flow_mol
#  16 - fs.separator.o2_poor_strm_state[0.0].mole_frac_comp[O2]
#  17 - fs.separator.o2_poor_strm_state[0.0].mole_frac_comp[N2]
#  18 - fs.separator.o2_poor_strm_state[0.0].temperature
#  19 - fs.separator.o2_poor_strm_state[0.0].pressure
#  20 - fs.separator.mixed_state[0.0].flow_mol_phase[Vap]
#  21 - fs.separator.mixed_state[0.0].mole_frac_phase_comp[Vap,O2]
#  22 - fs.separator.mixed_state[0.0].mole_frac_phase_comp[Vap,N2]
#  23 - fs.separator.mixed_state[0.0].phase_frac[Vap]
#  24 - fs.separator.o2_rich_strm_state[0.0].flow_mol_phase[Vap]
#  25 - fs.separator.o2_rich_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
#  26 - fs.separator.o2_rich_strm_state[0.0].mole_frac_phase_comp[Vap,N2]
#  27 - fs.separator.o2_rich_strm_state[0.0].phase_frac[Vap]
#  28 - fs.separator.o2_poor_strm_state[0.0].flow_mol_phase[Vap]
#  29 - fs.separator.o2_poor_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
#  30 - fs.separator.o2_poor_strm_state[0.0].mole_frac_phase_comp[Vap,N2]
#  31 - fs.separator.o2_poor_strm_state[0.0].phase_frac[Vap]
#
# ------------------------------------------------------------
# ACTIVATED CONSTRAINTS:
# ------------------------------------------------------------
#  1 - fs.separator.sum_split_frac[0.0,O2]
#  2 - fs.separator.sum_split_frac[0.0,N2]
#  3 - fs.separator.material_splitting_eqn[0.0,o2_rich_strm,O2]
#  4 - fs.separator.material_splitting_eqn[0.0,o2_rich_strm,N2]
#  5 - fs.separator.material_splitting_eqn[0.0,o2_poor_strm,O2]
#  6 - fs.separator.material_splitting_eqn[0.0,o2_poor_strm,N2]
#  7 - fs.separator.temperature_equality_eqn[0.0,o2_rich_strm]
#  8 - fs.separator.temperature_equality_eqn[0.0,o2_poor_strm]
#  9 - fs.separator.pressure_equality_eqn[0.0,o2_rich_strm]
#  10 - fs.separator.pressure_equality_eqn[0.0,o2_poor_strm]
#  11 - fs.separator.mixed_state[0.0].total_flow_balance
#  12 - fs.separator.mixed_state[0.0].component_flow_balances[O2]
#  13 - fs.separator.mixed_state[0.0].component_flow_balances[N2]
#  14 - fs.separator.mixed_state[0.0].phase_fraction_constraint[Vap]
#  15 - fs.separator.o2_rich_strm_state[0.0].sum_mole_frac_out
#  16 - fs.separator.o2_rich_strm_state[0.0].total_flow_balance
#  17 - fs.separator.o2_rich_strm_state[0.0].component_flow_balances[O2]
#  18 - fs.separator.o2_rich_strm_state[0.0].component_flow_balances[N2]
#  19 - fs.separator.o2_rich_strm_state[0.0].phase_fraction_constraint[Vap]
#  20 - fs.separator.o2_poor_strm_state[0.0].sum_mole_frac_out
#  21 - fs.separator.o2_poor_strm_state[0.0].total_flow_balance
#  22 - fs.separator.o2_poor_strm_state[0.0].component_flow_balances[O2]
#  23 - fs.separator.o2_poor_strm_state[0.0].component_flow_balances[N2]
#  24 - fs.separator.o2_poor_strm_state[0.0].phase_fraction_constraint[Vap]
#
# ------------------------------------------------------------
# ACTIVATED EQUALITIES:
# ------------------------------------------------------------
#  1 - fs.separator.sum_split_frac[0.0,O2]
#  2 - fs.separator.sum_split_frac[0.0,N2]
#  3 - fs.separator.material_splitting_eqn[0.0,o2_rich_strm,O2]
#  4 - fs.separator.material_splitting_eqn[0.0,o2_rich_strm,N2]
#  5 - fs.separator.material_splitting_eqn[0.0,o2_poor_strm,O2]
#  6 - fs.separator.material_splitting_eqn[0.0,o2_poor_strm,N2]
#  7 - fs.separator.temperature_equality_eqn[0.0,o2_rich_strm]
#  8 - fs.separator.temperature_equality_eqn[0.0,o2_poor_strm]
#  9 - fs.separator.pressure_equality_eqn[0.0,o2_rich_strm]
#  10 - fs.separator.pressure_equality_eqn[0.0,o2_poor_strm]
#  11 - fs.separator.mixed_state[0.0].total_flow_balance
#  12 - fs.separator.mixed_state[0.0].component_flow_balances[O2]
#  13 - fs.separator.mixed_state[0.0].component_flow_balances[N2]
#  14 - fs.separator.mixed_state[0.0].phase_fraction_constraint[Vap]
#  15 - fs.separator.o2_rich_strm_state[0.0].sum_mole_frac_out
#  16 - fs.separator.o2_rich_strm_state[0.0].total_flow_balance
#  17 - fs.separator.o2_rich_strm_state[0.0].component_flow_balances[O2]
#  18 - fs.separator.o2_rich_strm_state[0.0].component_flow_balances[N2]
#  19 - fs.separator.o2_rich_strm_state[0.0].phase_fraction_constraint[Vap]
#  20 - fs.separator.o2_poor_strm_state[0.0].sum_mole_frac_out
#  21 - fs.separator.o2_poor_strm_state[0.0].total_flow_balance
#  22 - fs.separator.o2_poor_strm_state[0.0].component_flow_balances[O2]
#  23 - fs.separator.o2_poor_strm_state[0.0].component_flow_balances[N2]
#  24 - fs.separator.o2_poor_strm_state[0.0].phase_fraction_constraint[Vap]
#
# ------------------------------------------------------------
# UNFIXED VARIABLES:
# ------------------------------------------------------------
#  1 - fs.separator.split_fraction[0.0,o2_poor_strm,O2]
#  2 - fs.separator.split_fraction[0.0,o2_poor_strm,N2]
#  3 - fs.separator.o2_rich_strm_state[0.0].flow_mol
#  4 - fs.separator.o2_rich_strm_state[0.0].mole_frac_comp[O2]
#  5 - fs.separator.o2_rich_strm_state[0.0].mole_frac_comp[N2]
#  6 - fs.separator.o2_rich_strm_state[0.0].temperature
#  7 - fs.separator.o2_rich_strm_state[0.0].pressure
#  8 - fs.separator.o2_poor_strm_state[0.0].flow_mol
#  9 - fs.separator.o2_poor_strm_state[0.0].mole_frac_comp[O2]
#  10 - fs.separator.o2_poor_strm_state[0.0].mole_frac_comp[N2]
#  11 - fs.separator.o2_poor_strm_state[0.0].temperature
#  12 - fs.separator.o2_poor_strm_state[0.0].pressure
#  13 - fs.separator.mixed_state[0.0].flow_mol_phase[Vap]
#  14 - fs.separator.mixed_state[0.0].mole_frac_phase_comp[Vap,O2]
#  15 - fs.separator.mixed_state[0.0].mole_frac_phase_comp[Vap,N2]
#  16 - fs.separator.mixed_state[0.0].phase_frac[Vap]
#  17 - fs.separator.o2_rich_strm_state[0.0].flow_mol_phase[Vap]
#  18 - fs.separator.o2_rich_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
#  19 - fs.separator.o2_rich_strm_state[0.0].mole_frac_phase_comp[Vap,N2]
#  20 - fs.separator.o2_rich_strm_state[0.0].phase_frac[Vap]
#  21 - fs.separator.o2_poor_strm_state[0.0].flow_mol_phase[Vap]
#  22 - fs.separator.o2_poor_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
#  23 - fs.separator.o2_poor_strm_state[0.0].mole_frac_phase_comp[Vap,N2]
#  24 - fs.separator.o2_poor_strm_state[0.0].phase_frac[Vap]
#
# ------------------------------------------------------------
# FIXED VARIABLES:
# ------------------------------------------------------------
#  1 - fs.separator.mixed_state[0.0].flow_mol
#  2 - fs.separator.mixed_state[0.0].mole_frac_comp[O2]
#  3 - fs.separator.mixed_state[0.0].mole_frac_comp[N2]
#  4 - fs.separator.mixed_state[0.0].temperature
#  5 - fs.separator.mixed_state[0.0].pressure
#  6 - fs.separator.split_fraction[0.0,o2_rich_strm,O2]
#  7 - fs.separator.split_fraction[0.0,o2_rich_strm,N2]
# ============================================================
#
#
#
# ============================================================
#                   Separator Air - O2 Rich
# ============================================================
#
# STREAM PROPERTIES:
# Flow [mol/s]        : 3.325008e-02
# Temperature [K]     : 948.45
# Pressure [Pa]       : 101325.00
#
# MOLE FRACTIONS:
#   x_O2        : 9.999975e-01
#   x_N2        : 2.457550e-06
#
# DOF after Separator Air - O2 Rich: 0
#
# ------------------------------------------------------------
# MODEL STATISTICS REPORT:
# ------------------------------------------------------------
#
# ========================================================================
# Model Statistics  -  fs.separator
#
# Degrees of Freedom: 0
#
# Total No. Variables: 31
#     No. Fixed Variables: 7
#     No. Unused Variables: 0 (Fixed):0)
#     No. Variables only in Inequalities: 0 (Fixed: 0)
#
# Total No. Constraints: 24
#     No. Equality Constraints: 24 (Deactivated: 0)
#     No. Inequality Constraints: 0 (Deactivated: 0)
#
# No. Objectives: 0 (Deactivated: 0)
#
# No. Blocks: 4 (Deactivated: 0)
# No. Expressions: 78
# ========================================================================
#
#
# ------------------------------------------------------------
# VARIABLES:
# ------------------------------------------------------------
#  1 - fs.separator.mixed_state[0.0].flow_mol
#  2 - fs.separator.mixed_state[0.0].mole_frac_comp[O2]
#  3 - fs.separator.mixed_state[0.0].mole_frac_comp[N2]
#  4 - fs.separator.mixed_state[0.0].temperature
#  5 - fs.separator.mixed_state[0.0].pressure
#  6 - fs.separator.split_fraction[0.0,o2_rich_strm,O2]
#  7 - fs.separator.split_fraction[0.0,o2_rich_strm,N2]
#  8 - fs.separator.split_fraction[0.0,o2_poor_strm,O2]
#  9 - fs.separator.split_fraction[0.0,o2_poor_strm,N2]
#  10 - fs.separator.o2_rich_strm_state[0.0].flow_mol
#  11 - fs.separator.o2_rich_strm_state[0.0].mole_frac_comp[O2]
#  12 - fs.separator.o2_rich_strm_state[0.0].mole_frac_comp[N2]
#  13 - fs.separator.o2_rich_strm_state[0.0].temperature
#  14 - fs.separator.o2_rich_strm_state[0.0].pressure
#  15 - fs.separator.o2_poor_strm_state[0.0].flow_mol
#  16 - fs.separator.o2_poor_strm_state[0.0].mole_frac_comp[O2]
#  17 - fs.separator.o2_poor_strm_state[0.0].mole_frac_comp[N2]
#  18 - fs.separator.o2_poor_strm_state[0.0].temperature
#  19 - fs.separator.o2_poor_strm_state[0.0].pressure
#  20 - fs.separator.mixed_state[0.0].flow_mol_phase[Vap]
#  21 - fs.separator.mixed_state[0.0].mole_frac_phase_comp[Vap,O2]
#  22 - fs.separator.mixed_state[0.0].mole_frac_phase_comp[Vap,N2]
#  23 - fs.separator.mixed_state[0.0].phase_frac[Vap]
#  24 - fs.separator.o2_rich_strm_state[0.0].flow_mol_phase[Vap]
#  25 - fs.separator.o2_rich_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
#  26 - fs.separator.o2_rich_strm_state[0.0].mole_frac_phase_comp[Vap,N2]
#  27 - fs.separator.o2_rich_strm_state[0.0].phase_frac[Vap]
#  28 - fs.separator.o2_poor_strm_state[0.0].flow_mol_phase[Vap]
#  29 - fs.separator.o2_poor_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
#  30 - fs.separator.o2_poor_strm_state[0.0].mole_frac_phase_comp[Vap,N2]
#  31 - fs.separator.o2_poor_strm_state[0.0].phase_frac[Vap]
#
# ------------------------------------------------------------
# ACTIVATED CONSTRAINTS:
# ------------------------------------------------------------
#  1 - fs.separator.sum_split_frac[0.0,O2]
#  2 - fs.separator.sum_split_frac[0.0,N2]
#  3 - fs.separator.material_splitting_eqn[0.0,o2_rich_strm,O2]
#  4 - fs.separator.material_splitting_eqn[0.0,o2_rich_strm,N2]
#  5 - fs.separator.material_splitting_eqn[0.0,o2_poor_strm,O2]
#  6 - fs.separator.material_splitting_eqn[0.0,o2_poor_strm,N2]
#  7 - fs.separator.temperature_equality_eqn[0.0,o2_rich_strm]
#  8 - fs.separator.temperature_equality_eqn[0.0,o2_poor_strm]
#  9 - fs.separator.pressure_equality_eqn[0.0,o2_rich_strm]
#  10 - fs.separator.pressure_equality_eqn[0.0,o2_poor_strm]
#  11 - fs.separator.mixed_state[0.0].total_flow_balance
#  12 - fs.separator.mixed_state[0.0].component_flow_balances[O2]
#  13 - fs.separator.mixed_state[0.0].component_flow_balances[N2]
#  14 - fs.separator.mixed_state[0.0].phase_fraction_constraint[Vap]
#  15 - fs.separator.o2_rich_strm_state[0.0].sum_mole_frac_out
#  16 - fs.separator.o2_rich_strm_state[0.0].total_flow_balance
#  17 - fs.separator.o2_rich_strm_state[0.0].component_flow_balances[O2]
#  18 - fs.separator.o2_rich_strm_state[0.0].component_flow_balances[N2]
#  19 - fs.separator.o2_rich_strm_state[0.0].phase_fraction_constraint[Vap]
#  20 - fs.separator.o2_poor_strm_state[0.0].sum_mole_frac_out
#  21 - fs.separator.o2_poor_strm_state[0.0].total_flow_balance
#  22 - fs.separator.o2_poor_strm_state[0.0].component_flow_balances[O2]
#  23 - fs.separator.o2_poor_strm_state[0.0].component_flow_balances[N2]
#  24 - fs.separator.o2_poor_strm_state[0.0].phase_fraction_constraint[Vap]
#
# ------------------------------------------------------------
# ACTIVATED EQUALITIES:
# ------------------------------------------------------------
#  1 - fs.separator.sum_split_frac[0.0,O2]
#  2 - fs.separator.sum_split_frac[0.0,N2]
#  3 - fs.separator.material_splitting_eqn[0.0,o2_rich_strm,O2]
#  4 - fs.separator.material_splitting_eqn[0.0,o2_rich_strm,N2]
#  5 - fs.separator.material_splitting_eqn[0.0,o2_poor_strm,O2]
#  6 - fs.separator.material_splitting_eqn[0.0,o2_poor_strm,N2]
#  7 - fs.separator.temperature_equality_eqn[0.0,o2_rich_strm]
#  8 - fs.separator.temperature_equality_eqn[0.0,o2_poor_strm]
#  9 - fs.separator.pressure_equality_eqn[0.0,o2_rich_strm]
#  10 - fs.separator.pressure_equality_eqn[0.0,o2_poor_strm]
#  11 - fs.separator.mixed_state[0.0].total_flow_balance
#  12 - fs.separator.mixed_state[0.0].component_flow_balances[O2]
#  13 - fs.separator.mixed_state[0.0].component_flow_balances[N2]
#  14 - fs.separator.mixed_state[0.0].phase_fraction_constraint[Vap]
#  15 - fs.separator.o2_rich_strm_state[0.0].sum_mole_frac_out
#  16 - fs.separator.o2_rich_strm_state[0.0].total_flow_balance
#  17 - fs.separator.o2_rich_strm_state[0.0].component_flow_balances[O2]
#  18 - fs.separator.o2_rich_strm_state[0.0].component_flow_balances[N2]
#  19 - fs.separator.o2_rich_strm_state[0.0].phase_fraction_constraint[Vap]
#  20 - fs.separator.o2_poor_strm_state[0.0].sum_mole_frac_out
#  21 - fs.separator.o2_poor_strm_state[0.0].total_flow_balance
#  22 - fs.separator.o2_poor_strm_state[0.0].component_flow_balances[O2]
#  23 - fs.separator.o2_poor_strm_state[0.0].component_flow_balances[N2]
#  24 - fs.separator.o2_poor_strm_state[0.0].phase_fraction_constraint[Vap]
#
# ------------------------------------------------------------
# UNFIXED VARIABLES:
# ------------------------------------------------------------
#  1 - fs.separator.split_fraction[0.0,o2_poor_strm,O2]
#  2 - fs.separator.split_fraction[0.0,o2_poor_strm,N2]
#  3 - fs.separator.o2_rich_strm_state[0.0].flow_mol
#  4 - fs.separator.o2_rich_strm_state[0.0].mole_frac_comp[O2]
#  5 - fs.separator.o2_rich_strm_state[0.0].mole_frac_comp[N2]
#  6 - fs.separator.o2_rich_strm_state[0.0].temperature
#  7 - fs.separator.o2_rich_strm_state[0.0].pressure
#  8 - fs.separator.o2_poor_strm_state[0.0].flow_mol
#  9 - fs.separator.o2_poor_strm_state[0.0].mole_frac_comp[O2]
#  10 - fs.separator.o2_poor_strm_state[0.0].mole_frac_comp[N2]
#  11 - fs.separator.o2_poor_strm_state[0.0].temperature
#  12 - fs.separator.o2_poor_strm_state[0.0].pressure
#  13 - fs.separator.mixed_state[0.0].flow_mol_phase[Vap]
#  14 - fs.separator.mixed_state[0.0].mole_frac_phase_comp[Vap,O2]
#  15 - fs.separator.mixed_state[0.0].mole_frac_phase_comp[Vap,N2]
#  16 - fs.separator.mixed_state[0.0].phase_frac[Vap]
#  17 - fs.separator.o2_rich_strm_state[0.0].flow_mol_phase[Vap]
#  18 - fs.separator.o2_rich_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
#  19 - fs.separator.o2_rich_strm_state[0.0].mole_frac_phase_comp[Vap,N2]
#  20 - fs.separator.o2_rich_strm_state[0.0].phase_frac[Vap]
#  21 - fs.separator.o2_poor_strm_state[0.0].flow_mol_phase[Vap]
#  22 - fs.separator.o2_poor_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
#  23 - fs.separator.o2_poor_strm_state[0.0].mole_frac_phase_comp[Vap,N2]
#  24 - fs.separator.o2_poor_strm_state[0.0].phase_frac[Vap]
#
# ------------------------------------------------------------
# FIXED VARIABLES:
# ------------------------------------------------------------
#  1 - fs.separator.mixed_state[0.0].flow_mol
#  2 - fs.separator.mixed_state[0.0].mole_frac_comp[O2]
#  3 - fs.separator.mixed_state[0.0].mole_frac_comp[N2]
#  4 - fs.separator.mixed_state[0.0].temperature
#  5 - fs.separator.mixed_state[0.0].pressure
#  6 - fs.separator.split_fraction[0.0,o2_rich_strm,O2]
#  7 - fs.separator.split_fraction[0.0,o2_rich_strm,N2]
# ============================================================
#
#
#
# ============================================================
#                   Separator Air - O2 Poor
# ============================================================
#
# STREAM PROPERTIES:
# Flow [mol/s]        : 1.250836e-01
# Temperature [K]     : 948.45
# Pressure [Pa]       : 101325.00
#
# MOLE FRACTIONS:
#   x_O2        : 1.438710e-11
#   x_N2        : 1.000000e+00
#
# DOF after Separator Air - O2 Poor: 0
#
# ------------------------------------------------------------
# MODEL STATISTICS REPORT:
# ------------------------------------------------------------
#
# ========================================================================
# Model Statistics  -  fs.separator
#
# Degrees of Freedom: 0
#
# Total No. Variables: 31
#     No. Fixed Variables: 7
#     No. Unused Variables: 0 (Fixed):0)
#     No. Variables only in Inequalities: 0 (Fixed: 0)
#
# Total No. Constraints: 24
#     No. Equality Constraints: 24 (Deactivated: 0)
#     No. Inequality Constraints: 0 (Deactivated: 0)
#
# No. Objectives: 0 (Deactivated: 0)
#
# No. Blocks: 4 (Deactivated: 0)
# No. Expressions: 78
# ========================================================================
#
#
# ------------------------------------------------------------
# VARIABLES:
# ------------------------------------------------------------
#  1 - fs.separator.mixed_state[0.0].flow_mol
#  2 - fs.separator.mixed_state[0.0].mole_frac_comp[O2]
#  3 - fs.separator.mixed_state[0.0].mole_frac_comp[N2]
#  4 - fs.separator.mixed_state[0.0].temperature
#  5 - fs.separator.mixed_state[0.0].pressure
#  6 - fs.separator.split_fraction[0.0,o2_rich_strm,O2]
#  7 - fs.separator.split_fraction[0.0,o2_rich_strm,N2]
#  8 - fs.separator.split_fraction[0.0,o2_poor_strm,O2]
#  9 - fs.separator.split_fraction[0.0,o2_poor_strm,N2]
#  10 - fs.separator.o2_rich_strm_state[0.0].flow_mol
#  11 - fs.separator.o2_rich_strm_state[0.0].mole_frac_comp[O2]
#  12 - fs.separator.o2_rich_strm_state[0.0].mole_frac_comp[N2]
#  13 - fs.separator.o2_rich_strm_state[0.0].temperature
#  14 - fs.separator.o2_rich_strm_state[0.0].pressure
#  15 - fs.separator.o2_poor_strm_state[0.0].flow_mol
#  16 - fs.separator.o2_poor_strm_state[0.0].mole_frac_comp[O2]
#  17 - fs.separator.o2_poor_strm_state[0.0].mole_frac_comp[N2]
#  18 - fs.separator.o2_poor_strm_state[0.0].temperature
#  19 - fs.separator.o2_poor_strm_state[0.0].pressure
#  20 - fs.separator.mixed_state[0.0].flow_mol_phase[Vap]
#  21 - fs.separator.mixed_state[0.0].mole_frac_phase_comp[Vap,O2]
#  22 - fs.separator.mixed_state[0.0].mole_frac_phase_comp[Vap,N2]
#  23 - fs.separator.mixed_state[0.0].phase_frac[Vap]
#  24 - fs.separator.o2_rich_strm_state[0.0].flow_mol_phase[Vap]
#  25 - fs.separator.o2_rich_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
#  26 - fs.separator.o2_rich_strm_state[0.0].mole_frac_phase_comp[Vap,N2]
#  27 - fs.separator.o2_rich_strm_state[0.0].phase_frac[Vap]
#  28 - fs.separator.o2_poor_strm_state[0.0].flow_mol_phase[Vap]
#  29 - fs.separator.o2_poor_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
#  30 - fs.separator.o2_poor_strm_state[0.0].mole_frac_phase_comp[Vap,N2]
#  31 - fs.separator.o2_poor_strm_state[0.0].phase_frac[Vap]
#
# ------------------------------------------------------------
# ACTIVATED CONSTRAINTS:
# ------------------------------------------------------------
#  1 - fs.separator.sum_split_frac[0.0,O2]
#  2 - fs.separator.sum_split_frac[0.0,N2]
#  3 - fs.separator.material_splitting_eqn[0.0,o2_rich_strm,O2]
#  4 - fs.separator.material_splitting_eqn[0.0,o2_rich_strm,N2]
#  5 - fs.separator.material_splitting_eqn[0.0,o2_poor_strm,O2]
#  6 - fs.separator.material_splitting_eqn[0.0,o2_poor_strm,N2]
#  7 - fs.separator.temperature_equality_eqn[0.0,o2_rich_strm]
#  8 - fs.separator.temperature_equality_eqn[0.0,o2_poor_strm]
#  9 - fs.separator.pressure_equality_eqn[0.0,o2_rich_strm]
#  10 - fs.separator.pressure_equality_eqn[0.0,o2_poor_strm]
#  11 - fs.separator.mixed_state[0.0].total_flow_balance
#  12 - fs.separator.mixed_state[0.0].component_flow_balances[O2]
#  13 - fs.separator.mixed_state[0.0].component_flow_balances[N2]
#  14 - fs.separator.mixed_state[0.0].phase_fraction_constraint[Vap]
#  15 - fs.separator.o2_rich_strm_state[0.0].sum_mole_frac_out
#  16 - fs.separator.o2_rich_strm_state[0.0].total_flow_balance
#  17 - fs.separator.o2_rich_strm_state[0.0].component_flow_balances[O2]
#  18 - fs.separator.o2_rich_strm_state[0.0].component_flow_balances[N2]
#  19 - fs.separator.o2_rich_strm_state[0.0].phase_fraction_constraint[Vap]
#  20 - fs.separator.o2_poor_strm_state[0.0].sum_mole_frac_out
#  21 - fs.separator.o2_poor_strm_state[0.0].total_flow_balance
#  22 - fs.separator.o2_poor_strm_state[0.0].component_flow_balances[O2]
#  23 - fs.separator.o2_poor_strm_state[0.0].component_flow_balances[N2]
#  24 - fs.separator.o2_poor_strm_state[0.0].phase_fraction_constraint[Vap]
#
# ------------------------------------------------------------
# ACTIVATED EQUALITIES:
# ------------------------------------------------------------
#  1 - fs.separator.sum_split_frac[0.0,O2]
#  2 - fs.separator.sum_split_frac[0.0,N2]
#  3 - fs.separator.material_splitting_eqn[0.0,o2_rich_strm,O2]
#  4 - fs.separator.material_splitting_eqn[0.0,o2_rich_strm,N2]
#  5 - fs.separator.material_splitting_eqn[0.0,o2_poor_strm,O2]
#  6 - fs.separator.material_splitting_eqn[0.0,o2_poor_strm,N2]
#  7 - fs.separator.temperature_equality_eqn[0.0,o2_rich_strm]
#  8 - fs.separator.temperature_equality_eqn[0.0,o2_poor_strm]
#  9 - fs.separator.pressure_equality_eqn[0.0,o2_rich_strm]
#  10 - fs.separator.pressure_equality_eqn[0.0,o2_poor_strm]
#  11 - fs.separator.mixed_state[0.0].total_flow_balance
#  12 - fs.separator.mixed_state[0.0].component_flow_balances[O2]
#  13 - fs.separator.mixed_state[0.0].component_flow_balances[N2]
#  14 - fs.separator.mixed_state[0.0].phase_fraction_constraint[Vap]
#  15 - fs.separator.o2_rich_strm_state[0.0].sum_mole_frac_out
#  16 - fs.separator.o2_rich_strm_state[0.0].total_flow_balance
#  17 - fs.separator.o2_rich_strm_state[0.0].component_flow_balances[O2]
#  18 - fs.separator.o2_rich_strm_state[0.0].component_flow_balances[N2]
#  19 - fs.separator.o2_rich_strm_state[0.0].phase_fraction_constraint[Vap]
#  20 - fs.separator.o2_poor_strm_state[0.0].sum_mole_frac_out
#  21 - fs.separator.o2_poor_strm_state[0.0].total_flow_balance
#  22 - fs.separator.o2_poor_strm_state[0.0].component_flow_balances[O2]
#  23 - fs.separator.o2_poor_strm_state[0.0].component_flow_balances[N2]
#  24 - fs.separator.o2_poor_strm_state[0.0].phase_fraction_constraint[Vap]
#
# ------------------------------------------------------------
# UNFIXED VARIABLES:
# ------------------------------------------------------------
#  1 - fs.separator.split_fraction[0.0,o2_poor_strm,O2]
#  2 - fs.separator.split_fraction[0.0,o2_poor_strm,N2]
#  3 - fs.separator.o2_rich_strm_state[0.0].flow_mol
#  4 - fs.separator.o2_rich_strm_state[0.0].mole_frac_comp[O2]
#  5 - fs.separator.o2_rich_strm_state[0.0].mole_frac_comp[N2]
#  6 - fs.separator.o2_rich_strm_state[0.0].temperature
#  7 - fs.separator.o2_rich_strm_state[0.0].pressure
#  8 - fs.separator.o2_poor_strm_state[0.0].flow_mol
#  9 - fs.separator.o2_poor_strm_state[0.0].mole_frac_comp[O2]
#  10 - fs.separator.o2_poor_strm_state[0.0].mole_frac_comp[N2]
#  11 - fs.separator.o2_poor_strm_state[0.0].temperature
#  12 - fs.separator.o2_poor_strm_state[0.0].pressure
#  13 - fs.separator.mixed_state[0.0].flow_mol_phase[Vap]
#  14 - fs.separator.mixed_state[0.0].mole_frac_phase_comp[Vap,O2]
#  15 - fs.separator.mixed_state[0.0].mole_frac_phase_comp[Vap,N2]
#  16 - fs.separator.mixed_state[0.0].phase_frac[Vap]
#  17 - fs.separator.o2_rich_strm_state[0.0].flow_mol_phase[Vap]
#  18 - fs.separator.o2_rich_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
#  19 - fs.separator.o2_rich_strm_state[0.0].mole_frac_phase_comp[Vap,N2]
#  20 - fs.separator.o2_rich_strm_state[0.0].phase_frac[Vap]
#  21 - fs.separator.o2_poor_strm_state[0.0].flow_mol_phase[Vap]
#  22 - fs.separator.o2_poor_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
#  23 - fs.separator.o2_poor_strm_state[0.0].mole_frac_phase_comp[Vap,N2]
#  24 - fs.separator.o2_poor_strm_state[0.0].phase_frac[Vap]
#
# ------------------------------------------------------------
# FIXED VARIABLES:
# ------------------------------------------------------------
#  1 - fs.separator.mixed_state[0.0].flow_mol
#  2 - fs.separator.mixed_state[0.0].mole_frac_comp[O2]
#  3 - fs.separator.mixed_state[0.0].mole_frac_comp[N2]
#  4 - fs.separator.mixed_state[0.0].temperature
#  5 - fs.separator.mixed_state[0.0].pressure
#  6 - fs.separator.split_fraction[0.0,o2_rich_strm,O2]
#  7 - fs.separator.split_fraction[0.0,o2_rich_strm,N2]
# ============================================================
#
#
# WARNING (W1002): Setting Var
# 'fs.translator_o2.properties_in[0.0].mole_frac_phase_comp[Vap,N2]' to a
# numeric value `0.0` outside the bounds (1e-20, 1.001).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
#
# ============================================================
#                    Translator O2 - Inlet
# ============================================================
#
# STREAM PROPERTIES:
# Flow [mol/s]        : 3.325008e-02
# Temperature [K]     : 948.45
# Pressure [Pa]       : 101325.00
#
# MOLE FRACTIONS:
#   x_O2        : 9.999975e-01
#   x_N2        : 0.000000e+00
#
# DOF after Translator O2 - Inlet: -1
#
# ------------------------------------------------------------
# MODEL STATISTICS REPORT:
# ------------------------------------------------------------
#
# ========================================================================
# Model Statistics  -  fs.translator_o2
#
# Degrees of Freedom: -1
#
# Total No. Variables: 20
#     No. Fixed Variables: 8
#     No. Unused Variables: 0 (Fixed):0)
#     No. Variables only in Inequalities: 0 (Fixed: 0)
#
# Total No. Constraints: 13
#     No. Equality Constraints: 13 (Deactivated: 0)
#     No. Inequality Constraints: 0 (Deactivated: 0)
#
# No. Objectives: 0 (Deactivated: 0)
#
# No. Blocks: 3 (Deactivated: 0)
# No. Expressions: 65
# ========================================================================
#
#
# ------------------------------------------------------------
# VARIABLES:
# ------------------------------------------------------------
#  1 - fs.translator_o2.properties_in[0.0].flow_mol
#  2 - fs.translator_o2.properties_in[0.0].mole_frac_comp[O2]
#  3 - fs.translator_o2.properties_in[0.0].mole_frac_comp[N2]
#  4 - fs.translator_o2.properties_in[0.0].temperature
#  5 - fs.translator_o2.properties_in[0.0].pressure
#  6 - fs.translator_o2.properties_out[0.0].flow_mol
#  7 - fs.translator_o2.properties_out[0.0].mole_frac_comp[H2]
#  8 - fs.translator_o2.properties_out[0.0].mole_frac_comp[H2O]
#  9 - fs.translator_o2.properties_out[0.0].mole_frac_comp[O2]
#  10 - fs.translator_o2.properties_out[0.0].temperature
#  11 - fs.translator_o2.properties_out[0.0].pressure
#  12 - fs.translator_o2.properties_in[0.0].flow_mol_phase[Vap]
#  13 - fs.translator_o2.properties_in[0.0].mole_frac_phase_comp[Vap,O2]
#  14 - fs.translator_o2.properties_in[0.0].mole_frac_phase_comp[Vap,N2]
#  15 - fs.translator_o2.properties_in[0.0].phase_frac[Vap]
#  16 - fs.translator_o2.properties_out[0.0].flow_mol_phase[Vap]
#  17 - fs.translator_o2.properties_out[0.0].mole_frac_phase_comp[Vap,H2]
#  18 - fs.translator_o2.properties_out[0.0].mole_frac_phase_comp[Vap,H2O]
#  19 - fs.translator_o2.properties_out[0.0].mole_frac_phase_comp[Vap,O2]
#  20 - fs.translator_o2.properties_out[0.0].phase_frac[Vap]
#
# ------------------------------------------------------------
# ACTIVATED CONSTRAINTS:
# ------------------------------------------------------------
#  1 - fs.translator_o2.temp_eqn_o2[0.0]
#  2 - fs.translator_o2.press_eqn_o2[0.0]
#  3 - fs.translator_o2.flow_eqn_o2[0.0]
#  4 - fs.translator_o2.properties_in[0.0].total_flow_balance
#  5 - fs.translator_o2.properties_in[0.0].component_flow_balances[O2]
#  6 - fs.translator_o2.properties_in[0.0].component_flow_balances[N2]
#  7 - fs.translator_o2.properties_in[0.0].phase_fraction_constraint[Vap]
#  8 - fs.translator_o2.properties_out[0.0].sum_mole_frac_out
#  9 - fs.translator_o2.properties_out[0.0].total_flow_balance
#  10 - fs.translator_o2.properties_out[0.0].component_flow_balances[H2]
#  11 - fs.translator_o2.properties_out[0.0].component_flow_balances[H2O]
#  12 - fs.translator_o2.properties_out[0.0].component_flow_balances[O2]
#  13 - fs.translator_o2.properties_out[0.0].phase_fraction_constraint[Vap]
#
# ------------------------------------------------------------
# ACTIVATED EQUALITIES:
# ------------------------------------------------------------
#  1 - fs.translator_o2.temp_eqn_o2[0.0]
#  2 - fs.translator_o2.press_eqn_o2[0.0]
#  3 - fs.translator_o2.flow_eqn_o2[0.0]
#  4 - fs.translator_o2.properties_in[0.0].total_flow_balance
#  5 - fs.translator_o2.properties_in[0.0].component_flow_balances[O2]
#  6 - fs.translator_o2.properties_in[0.0].component_flow_balances[N2]
#  7 - fs.translator_o2.properties_in[0.0].phase_fraction_constraint[Vap]
#  8 - fs.translator_o2.properties_out[0.0].sum_mole_frac_out
#  9 - fs.translator_o2.properties_out[0.0].total_flow_balance
#  10 - fs.translator_o2.properties_out[0.0].component_flow_balances[H2]
#  11 - fs.translator_o2.properties_out[0.0].component_flow_balances[H2O]
#  12 - fs.translator_o2.properties_out[0.0].component_flow_balances[O2]
#  13 - fs.translator_o2.properties_out[0.0].phase_fraction_constraint[Vap]
#
# ------------------------------------------------------------
# UNFIXED VARIABLES:
# ------------------------------------------------------------
#  1 - fs.translator_o2.properties_in[0.0].flow_mol
#  2 - fs.translator_o2.properties_in[0.0].mole_frac_comp[O2]
#  3 - fs.translator_o2.properties_out[0.0].flow_mol
#  4 - fs.translator_o2.properties_in[0.0].flow_mol_phase[Vap]
#  5 - fs.translator_o2.properties_in[0.0].mole_frac_phase_comp[Vap,O2]
#  6 - fs.translator_o2.properties_in[0.0].mole_frac_phase_comp[Vap,N2]
#  7 - fs.translator_o2.properties_in[0.0].phase_frac[Vap]
#  8 - fs.translator_o2.properties_out[0.0].flow_mol_phase[Vap]
#  9 - fs.translator_o2.properties_out[0.0].mole_frac_phase_comp[Vap,H2]
#  10 - fs.translator_o2.properties_out[0.0].mole_frac_phase_comp[Vap,H2O]
#  11 - fs.translator_o2.properties_out[0.0].mole_frac_phase_comp[Vap,O2]
#  12 - fs.translator_o2.properties_out[0.0].phase_frac[Vap]
#
# ------------------------------------------------------------
# FIXED VARIABLES:
# ------------------------------------------------------------
#  1 - fs.translator_o2.properties_in[0.0].mole_frac_comp[N2]
#  2 - fs.translator_o2.properties_in[0.0].temperature
#  3 - fs.translator_o2.properties_in[0.0].pressure
#  4 - fs.translator_o2.properties_out[0.0].mole_frac_comp[H2]
#  5 - fs.translator_o2.properties_out[0.0].mole_frac_comp[H2O]
#  6 - fs.translator_o2.properties_out[0.0].mole_frac_comp[O2]
#  7 - fs.translator_o2.properties_out[0.0].temperature
#  8 - fs.translator_o2.properties_out[0.0].pressure
# ============================================================
#
#
#
# ============================================================
#                    Translator O2 - Outlet
# ============================================================
#
# STREAM PROPERTIES:
# Flow [mol/s]        : 8.000000e+03
# Temperature [K]     : 948.45
# Pressure [Pa]       : 101325.00
#
# MOLE FRACTIONS:
#   x_H2        : 1.000000e-19
#   x_H2O       : 1.000000e-19
#   x_O2        : 1.000000e+00
#
# DOF after Translator O2 - Outlet: -1
#
# ------------------------------------------------------------
# MODEL STATISTICS REPORT:
# ------------------------------------------------------------
#
# ========================================================================
# Model Statistics  -  fs.translator_o2
#
# Degrees of Freedom: -1
#
# Total No. Variables: 20
#     No. Fixed Variables: 8
#     No. Unused Variables: 0 (Fixed):0)
#     No. Variables only in Inequalities: 0 (Fixed: 0)
#
# Total No. Constraints: 13
#     No. Equality Constraints: 13 (Deactivated: 0)
#     No. Inequality Constraints: 0 (Deactivated: 0)
#
# No. Objectives: 0 (Deactivated: 0)
#
# No. Blocks: 3 (Deactivated: 0)
# No. Expressions: 65
# ========================================================================
#
#
# ------------------------------------------------------------
# VARIABLES:
# ------------------------------------------------------------
#  1 - fs.translator_o2.properties_in[0.0].flow_mol
#  2 - fs.translator_o2.properties_in[0.0].mole_frac_comp[O2]
#  3 - fs.translator_o2.properties_in[0.0].mole_frac_comp[N2]
#  4 - fs.translator_o2.properties_in[0.0].temperature
#  5 - fs.translator_o2.properties_in[0.0].pressure
#  6 - fs.translator_o2.properties_out[0.0].flow_mol
#  7 - fs.translator_o2.properties_out[0.0].mole_frac_comp[H2]
#  8 - fs.translator_o2.properties_out[0.0].mole_frac_comp[H2O]
#  9 - fs.translator_o2.properties_out[0.0].mole_frac_comp[O2]
#  10 - fs.translator_o2.properties_out[0.0].temperature
#  11 - fs.translator_o2.properties_out[0.0].pressure
#  12 - fs.translator_o2.properties_in[0.0].flow_mol_phase[Vap]
#  13 - fs.translator_o2.properties_in[0.0].mole_frac_phase_comp[Vap,O2]
#  14 - fs.translator_o2.properties_in[0.0].mole_frac_phase_comp[Vap,N2]
#  15 - fs.translator_o2.properties_in[0.0].phase_frac[Vap]
#  16 - fs.translator_o2.properties_out[0.0].flow_mol_phase[Vap]
#  17 - fs.translator_o2.properties_out[0.0].mole_frac_phase_comp[Vap,H2]
#  18 - fs.translator_o2.properties_out[0.0].mole_frac_phase_comp[Vap,H2O]
#  19 - fs.translator_o2.properties_out[0.0].mole_frac_phase_comp[Vap,O2]
#  20 - fs.translator_o2.properties_out[0.0].phase_frac[Vap]
#
# ------------------------------------------------------------
# ACTIVATED CONSTRAINTS:
# ------------------------------------------------------------
#  1 - fs.translator_o2.temp_eqn_o2[0.0]
#  2 - fs.translator_o2.press_eqn_o2[0.0]
#  3 - fs.translator_o2.flow_eqn_o2[0.0]
#  4 - fs.translator_o2.properties_in[0.0].total_flow_balance
#  5 - fs.translator_o2.properties_in[0.0].component_flow_balances[O2]
#  6 - fs.translator_o2.properties_in[0.0].component_flow_balances[N2]
#  7 - fs.translator_o2.properties_in[0.0].phase_fraction_constraint[Vap]
#  8 - fs.translator_o2.properties_out[0.0].sum_mole_frac_out
#  9 - fs.translator_o2.properties_out[0.0].total_flow_balance
#  10 - fs.translator_o2.properties_out[0.0].component_flow_balances[H2]
#  11 - fs.translator_o2.properties_out[0.0].component_flow_balances[H2O]
#  12 - fs.translator_o2.properties_out[0.0].component_flow_balances[O2]
#  13 - fs.translator_o2.properties_out[0.0].phase_fraction_constraint[Vap]
#
# ------------------------------------------------------------
# ACTIVATED EQUALITIES:
# ------------------------------------------------------------
#  1 - fs.translator_o2.temp_eqn_o2[0.0]
#  2 - fs.translator_o2.press_eqn_o2[0.0]
#  3 - fs.translator_o2.flow_eqn_o2[0.0]
#  4 - fs.translator_o2.properties_in[0.0].total_flow_balance
#  5 - fs.translator_o2.properties_in[0.0].component_flow_balances[O2]
#  6 - fs.translator_o2.properties_in[0.0].component_flow_balances[N2]
#  7 - fs.translator_o2.properties_in[0.0].phase_fraction_constraint[Vap]
#  8 - fs.translator_o2.properties_out[0.0].sum_mole_frac_out
#  9 - fs.translator_o2.properties_out[0.0].total_flow_balance
# ...
#  7 - fs.mixer2.o2_strm_state[0.0].component_flow_balances[N2]
#  8 - fs.mixer2.o2_strm_state[0.0].phase_fraction_constraint[Vap]
#  9 - fs.mixer2.o2_poor_strm_state[0.0].total_flow_balance
#  10 - fs.mixer2.o2_poor_strm_state[0.0].component_flow_balances[O2]
#  11 - fs.mixer2.o2_poor_strm_state[0.0].component_flow_balances[N2]
#  12 - fs.mixer2.o2_poor_strm_state[0.0].phase_fraction_constraint[Vap]
#  13 - fs.mixer2.mixed_state[0.0].sum_mole_frac_out
#  14 - fs.mixer2.mixed_state[0.0].total_flow_balance
#  15 - fs.mixer2.mixed_state[0.0].component_flow_balances[O2]
#  16 - fs.mixer2.mixed_state[0.0].component_flow_balances[N2]
#  17 - fs.mixer2.mixed_state[0.0].phase_fraction_constraint[Vap]
#
# ------------------------------------------------------------
# UNFIXED VARIABLES:
# ------------------------------------------------------------
#  1 - fs.mixer2.o2_strm_state[0.0].flow_mol
#  2 - fs.mixer2.o2_strm_state[0.0].mole_frac_comp[O2]
#  3 - fs.mixer2.o2_strm_state[0.0].mole_frac_comp[N2]
#  4 - fs.mixer2.o2_strm_state[0.0].temperature
#  5 - fs.mixer2.o2_strm_state[0.0].pressure
#  6 - fs.mixer2.o2_poor_strm_state[0.0].flow_mol
#  7 - fs.mixer2.o2_poor_strm_state[0.0].mole_frac_comp[O2]
#  8 - fs.mixer2.o2_poor_strm_state[0.0].mole_frac_comp[N2]
#  9 - fs.mixer2.o2_poor_strm_state[0.0].temperature
#  10 - fs.mixer2.o2_poor_strm_state[0.0].pressure
#  11 - fs.mixer2.mixed_state[0.0].flow_mol
#  12 - fs.mixer2.mixed_state[0.0].mole_frac_comp[O2]
#  13 - fs.mixer2.mixed_state[0.0].mole_frac_comp[N2]
#  14 - fs.mixer2.mixed_state[0.0].temperature
#  15 - fs.mixer2.mixed_state[0.0].pressure
#  16 - fs.mixer2.o2_strm_state[0.0].flow_mol_phase[Vap]
#  17 - fs.mixer2.o2_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
#  18 - fs.mixer2.o2_strm_state[0.0].mole_frac_phase_comp[Vap,N2]
#  19 - fs.mixer2.o2_strm_state[0.0].phase_frac[Vap]
#  20 - fs.mixer2.o2_poor_strm_state[0.0].flow_mol_phase[Vap]
#  21 - fs.mixer2.o2_poor_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
#  22 - fs.mixer2.o2_poor_strm_state[0.0].mole_frac_phase_comp[Vap,N2]
#  23 - fs.mixer2.o2_poor_strm_state[0.0].phase_frac[Vap]
#  24 - fs.mixer2.mixed_state[0.0].flow_mol_phase[Vap]
#  25 - fs.mixer2.mixed_state[0.0].mole_frac_phase_comp[Vap,O2]
#  26 - fs.mixer2.mixed_state[0.0].mole_frac_phase_comp[Vap,N2]
#  27 - fs.mixer2.mixed_state[0.0].phase_frac[Vap]
#
# ------------------------------------------------------------
# FIXED VARIABLES:
# ------------------------------------------------------------
# ============================================================
#
#
#
# ============================================================
#                 Mixer - O2 poor stram Inlet
# ============================================================
#
# STREAM PROPERTIES:
# Flow [mol/s]        : 8.000000e+03
# Temperature [K]     : 500.00
# Pressure [Pa]       : 130000.00
#
# MOLE FRACTIONS:
#   x_O2        : 5.000000e-01
#   x_N2        : 5.000000e-01
#
# DOF after Mixer - O2 poor stram Inlet: 10
#
# ------------------------------------------------------------
# MODEL STATISTICS REPORT:
# ------------------------------------------------------------
#
# ========================================================================
# Model Statistics  -  fs.mixer2
#
# Degrees of Freedom: 10
#
# Total No. Variables: 27
#     No. Fixed Variables: 0
#     No. Unused Variables: 0 (Fixed):0)
#     No. Variables only in Inequalities: 0 (Fixed: 0)
#
# Total No. Constraints: 17
#     No. Equality Constraints: 17 (Deactivated: 0)
#     No. Inequality Constraints: 0 (Deactivated: 0)
#
# No. Objectives: 0 (Deactivated: 0)
#
# No. Blocks: 4 (Deactivated: 0)
# No. Expressions: 87
# ========================================================================
#
#
# ------------------------------------------------------------
# VARIABLES:
# ------------------------------------------------------------
#  1 - fs.mixer2.o2_strm_state[0.0].flow_mol
#  2 - fs.mixer2.o2_strm_state[0.0].mole_frac_comp[O2]
#  3 - fs.mixer2.o2_strm_state[0.0].mole_frac_comp[N2]
#  4 - fs.mixer2.o2_strm_state[0.0].temperature
#  5 - fs.mixer2.o2_strm_state[0.0].pressure
#  6 - fs.mixer2.o2_poor_strm_state[0.0].flow_mol
#  7 - fs.mixer2.o2_poor_strm_state[0.0].mole_frac_comp[O2]
#  8 - fs.mixer2.o2_poor_strm_state[0.0].mole_frac_comp[N2]
#  9 - fs.mixer2.o2_poor_strm_state[0.0].temperature
#  10 - fs.mixer2.o2_poor_strm_state[0.0].pressure
#  11 - fs.mixer2.mixed_state[0.0].flow_mol
#  12 - fs.mixer2.mixed_state[0.0].mole_frac_comp[O2]
#  13 - fs.mixer2.mixed_state[0.0].mole_frac_comp[N2]
#  14 - fs.mixer2.mixed_state[0.0].temperature
#  15 - fs.mixer2.mixed_state[0.0].pressure
#  16 - fs.mixer2.o2_strm_state[0.0].flow_mol_phase[Vap]
#  17 - fs.mixer2.o2_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
#  18 - fs.mixer2.o2_strm_state[0.0].mole_frac_phase_comp[Vap,N2]
#  19 - fs.mixer2.o2_strm_state[0.0].phase_frac[Vap]
#  20 - fs.mixer2.o2_poor_strm_state[0.0].flow_mol_phase[Vap]
#  21 - fs.mixer2.o2_poor_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
#  22 - fs.mixer2.o2_poor_strm_state[0.0].mole_frac_phase_comp[Vap,N2]
#  23 - fs.mixer2.o2_poor_strm_state[0.0].phase_frac[Vap]
#  24 - fs.mixer2.mixed_state[0.0].flow_mol_phase[Vap]
#  25 - fs.mixer2.mixed_state[0.0].mole_frac_phase_comp[Vap,O2]
#  26 - fs.mixer2.mixed_state[0.0].mole_frac_phase_comp[Vap,N2]
#  27 - fs.mixer2.mixed_state[0.0].phase_frac[Vap]
#
# ------------------------------------------------------------
# ACTIVATED CONSTRAINTS:
# ------------------------------------------------------------
#  1 - fs.mixer2.material_mixing_equations[0.0,O2]
#  2 - fs.mixer2.material_mixing_equations[0.0,N2]
#  3 - fs.mixer2.enthalpy_mixing_equations[0.0]
#  4 - fs.mixer2.pressure_eqn[0.0]
#  5 - fs.mixer2.o2_strm_state[0.0].total_flow_balance
#  6 - fs.mixer2.o2_strm_state[0.0].component_flow_balances[O2]
#  7 - fs.mixer2.o2_strm_state[0.0].component_flow_balances[N2]
#  8 - fs.mixer2.o2_strm_state[0.0].phase_fraction_constraint[Vap]
#  9 - fs.mixer2.o2_poor_strm_state[0.0].total_flow_balance
#  10 - fs.mixer2.o2_poor_strm_state[0.0].component_flow_balances[O2]
#  11 - fs.mixer2.o2_poor_strm_state[0.0].component_flow_balances[N2]
#  12 - fs.mixer2.o2_poor_strm_state[0.0].phase_fraction_constraint[Vap]
#  13 - fs.mixer2.mixed_state[0.0].sum_mole_frac_out
#  14 - fs.mixer2.mixed_state[0.0].total_flow_balance
#  15 - fs.mixer2.mixed_state[0.0].component_flow_balances[O2]
#  16 - fs.mixer2.mixed_state[0.0].component_flow_balances[N2]
#  17 - fs.mixer2.mixed_state[0.0].phase_fraction_constraint[Vap]
#
# ------------------------------------------------------------
# ACTIVATED EQUALITIES:
# ------------------------------------------------------------
#  1 - fs.mixer2.material_mixing_equations[0.0,O2]
#  2 - fs.mixer2.material_mixing_equations[0.0,N2]
#  3 - fs.mixer2.enthalpy_mixing_equations[0.0]
#  4 - fs.mixer2.pressure_eqn[0.0]
#  5 - fs.mixer2.o2_strm_state[0.0].total_flow_balance
#  6 - fs.mixer2.o2_strm_state[0.0].component_flow_balances[O2]
#  7 - fs.mixer2.o2_strm_state[0.0].component_flow_balances[N2]
#  8 - fs.mixer2.o2_strm_state[0.0].phase_fraction_constraint[Vap]
#  9 - fs.mixer2.o2_poor_strm_state[0.0].total_flow_balance
#  10 - fs.mixer2.o2_poor_strm_state[0.0].component_flow_balances[O2]
#  11 - fs.mixer2.o2_poor_strm_state[0.0].component_flow_balances[N2]
#  12 - fs.mixer2.o2_poor_strm_state[0.0].phase_fraction_constraint[Vap]
#  13 - fs.mixer2.mixed_state[0.0].sum_mole_frac_out
#  14 - fs.mixer2.mixed_state[0.0].total_flow_balance
#  15 - fs.mixer2.mixed_state[0.0].component_flow_balances[O2]
#  16 - fs.mixer2.mixed_state[0.0].component_flow_balances[N2]
#  17 - fs.mixer2.mixed_state[0.0].phase_fraction_constraint[Vap]
#
# ------------------------------------------------------------
# UNFIXED VARIABLES:
# ------------------------------------------------------------
#  1 - fs.mixer2.o2_strm_state[0.0].flow_mol
#  2 - fs.mixer2.o2_strm_state[0.0].mole_frac_comp[O2]
#  3 - fs.mixer2.o2_strm_state[0.0].mole_frac_comp[N2]
#  4 - fs.mixer2.o2_strm_state[0.0].temperature
#  5 - fs.mixer2.o2_strm_state[0.0].pressure
#  6 - fs.mixer2.o2_poor_strm_state[0.0].flow_mol
#  7 - fs.mixer2.o2_poor_strm_state[0.0].mole_frac_comp[O2]
#  8 - fs.mixer2.o2_poor_strm_state[0.0].mole_frac_comp[N2]
#  9 - fs.mixer2.o2_poor_strm_state[0.0].temperature
#  10 - fs.mixer2.o2_poor_strm_state[0.0].pressure
#  11 - fs.mixer2.mixed_state[0.0].flow_mol
#  12 - fs.mixer2.mixed_state[0.0].mole_frac_comp[O2]
#  13 - fs.mixer2.mixed_state[0.0].mole_frac_comp[N2]
#  14 - fs.mixer2.mixed_state[0.0].temperature
#  15 - fs.mixer2.mixed_state[0.0].pressure
#  16 - fs.mixer2.o2_strm_state[0.0].flow_mol_phase[Vap]
#  17 - fs.mixer2.o2_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
#  18 - fs.mixer2.o2_strm_state[0.0].mole_frac_phase_comp[Vap,N2]
#  19 - fs.mixer2.o2_strm_state[0.0].phase_frac[Vap]
#  20 - fs.mixer2.o2_poor_strm_state[0.0].flow_mol_phase[Vap]
#  21 - fs.mixer2.o2_poor_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
#  22 - fs.mixer2.o2_poor_strm_state[0.0].mole_frac_phase_comp[Vap,N2]
#  23 - fs.mixer2.o2_poor_strm_state[0.0].phase_frac[Vap]
#  24 - fs.mixer2.mixed_state[0.0].flow_mol_phase[Vap]
#  25 - fs.mixer2.mixed_state[0.0].mole_frac_phase_comp[Vap,O2]
#  26 - fs.mixer2.mixed_state[0.0].mole_frac_phase_comp[Vap,N2]
#  27 - fs.mixer2.mixed_state[0.0].phase_frac[Vap]
#
# ------------------------------------------------------------
# FIXED VARIABLES:
# ------------------------------------------------------------
# ============================================================
#
#
#
# ============================================================
#                     Mixer - Mixed Outlet
# ============================================================
#
# STREAM PROPERTIES:
# Flow [mol/s]        : 1.600000e+04
# Temperature [K]     : 500.00
# Pressure [Pa]       : 130000.00
#
# MOLE FRACTIONS:
#   x_O2        : 7.499998e-01
#   x_N2        : 2.500002e-01
#
# DOF after Mixer - Mixed Outlet: 10
#
# ------------------------------------------------------------
# MODEL STATISTICS REPORT:
# ------------------------------------------------------------
#
# ========================================================================
# Model Statistics  -  fs.mixer2
#
# Degrees of Freedom: 10
#
# Total No. Variables: 27
#     No. Fixed Variables: 0
#     No. Unused Variables: 0 (Fixed):0)
#     No. Variables only in Inequalities: 0 (Fixed: 0)
#
# Total No. Constraints: 17
#     No. Equality Constraints: 17 (Deactivated: 0)
#     No. Inequality Constraints: 0 (Deactivated: 0)
#
# No. Objectives: 0 (Deactivated: 0)
#
# No. Blocks: 4 (Deactivated: 0)
# No. Expressions: 87
# ========================================================================
#
#
# ------------------------------------------------------------
# VARIABLES:
# ------------------------------------------------------------
#  1 - fs.mixer2.o2_strm_state[0.0].flow_mol
#  2 - fs.mixer2.o2_strm_state[0.0].mole_frac_comp[O2]
#  3 - fs.mixer2.o2_strm_state[0.0].mole_frac_comp[N2]
#  4 - fs.mixer2.o2_strm_state[0.0].temperature
#  5 - fs.mixer2.o2_strm_state[0.0].pressure
#  6 - fs.mixer2.o2_poor_strm_state[0.0].flow_mol
#  7 - fs.mixer2.o2_poor_strm_state[0.0].mole_frac_comp[O2]
#  8 - fs.mixer2.o2_poor_strm_state[0.0].mole_frac_comp[N2]
#  9 - fs.mixer2.o2_poor_strm_state[0.0].temperature
#  10 - fs.mixer2.o2_poor_strm_state[0.0].pressure
#  11 - fs.mixer2.mixed_state[0.0].flow_mol
#  12 - fs.mixer2.mixed_state[0.0].mole_frac_comp[O2]
#  13 - fs.mixer2.mixed_state[0.0].mole_frac_comp[N2]
#  14 - fs.mixer2.mixed_state[0.0].temperature
#  15 - fs.mixer2.mixed_state[0.0].pressure
#  16 - fs.mixer2.o2_strm_state[0.0].flow_mol_phase[Vap]
#  17 - fs.mixer2.o2_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
#  18 - fs.mixer2.o2_strm_state[0.0].mole_frac_phase_comp[Vap,N2]
#  19 - fs.mixer2.o2_strm_state[0.0].phase_frac[Vap]
#  20 - fs.mixer2.o2_poor_strm_state[0.0].flow_mol_phase[Vap]
#  21 - fs.mixer2.o2_poor_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
#  22 - fs.mixer2.o2_poor_strm_state[0.0].mole_frac_phase_comp[Vap,N2]
#  23 - fs.mixer2.o2_poor_strm_state[0.0].phase_frac[Vap]
#  24 - fs.mixer2.mixed_state[0.0].flow_mol_phase[Vap]
#  25 - fs.mixer2.mixed_state[0.0].mole_frac_phase_comp[Vap,O2]
#  26 - fs.mixer2.mixed_state[0.0].mole_frac_phase_comp[Vap,N2]
#  27 - fs.mixer2.mixed_state[0.0].phase_frac[Vap]
#
# ------------------------------------------------------------
# ACTIVATED CONSTRAINTS:
# ------------------------------------------------------------
#  1 - fs.mixer2.material_mixing_equations[0.0,O2]
#  2 - fs.mixer2.material_mixing_equations[0.0,N2]
#  3 - fs.mixer2.enthalpy_mixing_equations[0.0]
#  4 - fs.mixer2.pressure_eqn[0.0]
#  5 - fs.mixer2.o2_strm_state[0.0].total_flow_balance
#  6 - fs.mixer2.o2_strm_state[0.0].component_flow_balances[O2]
#  7 - fs.mixer2.o2_strm_state[0.0].component_flow_balances[N2]
#  8 - fs.mixer2.o2_strm_state[0.0].phase_fraction_constraint[Vap]
#  9 - fs.mixer2.o2_poor_strm_state[0.0].total_flow_balance
#  10 - fs.mixer2.o2_poor_strm_state[0.0].component_flow_balances[O2]
#  11 - fs.mixer2.o2_poor_strm_state[0.0].component_flow_balances[N2]
#  12 - fs.mixer2.o2_poor_strm_state[0.0].phase_fraction_constraint[Vap]
#  13 - fs.mixer2.mixed_state[0.0].sum_mole_frac_out
#  14 - fs.mixer2.mixed_state[0.0].total_flow_balance
#  15 - fs.mixer2.mixed_state[0.0].component_flow_balances[O2]
#  16 - fs.mixer2.mixed_state[0.0].component_flow_balances[N2]
#  17 - fs.mixer2.mixed_state[0.0].phase_fraction_constraint[Vap]
#
# ------------------------------------------------------------
# ACTIVATED EQUALITIES:
# ------------------------------------------------------------
#  1 - fs.mixer2.material_mixing_equations[0.0,O2]
#  2 - fs.mixer2.material_mixing_equations[0.0,N2]
#  3 - fs.mixer2.enthalpy_mixing_equations[0.0]
#  4 - fs.mixer2.pressure_eqn[0.0]
#  5 - fs.mixer2.o2_strm_state[0.0].total_flow_balance
#  6 - fs.mixer2.o2_strm_state[0.0].component_flow_balances[O2]
#  7 - fs.mixer2.o2_strm_state[0.0].component_flow_balances[N2]
#  8 - fs.mixer2.o2_strm_state[0.0].phase_fraction_constraint[Vap]
#  9 - fs.mixer2.o2_poor_strm_state[0.0].total_flow_balance
#  10 - fs.mixer2.o2_poor_strm_state[0.0].component_flow_balances[O2]
#  11 - fs.mixer2.o2_poor_strm_state[0.0].component_flow_balances[N2]
#  12 - fs.mixer2.o2_poor_strm_state[0.0].phase_fraction_constraint[Vap]
#  13 - fs.mixer2.mixed_state[0.0].sum_mole_frac_out
#  14 - fs.mixer2.mixed_state[0.0].total_flow_balance
#  15 - fs.mixer2.mixed_state[0.0].component_flow_balances[O2]
#  16 - fs.mixer2.mixed_state[0.0].component_flow_balances[N2]
#  17 - fs.mixer2.mixed_state[0.0].phase_fraction_constraint[Vap]
#
# ------------------------------------------------------------
# UNFIXED VARIABLES:
# ------------------------------------------------------------
#  1 - fs.mixer2.o2_strm_state[0.0].flow_mol
#  2 - fs.mixer2.o2_strm_state[0.0].mole_frac_comp[O2]
#  3 - fs.mixer2.o2_strm_state[0.0].mole_frac_comp[N2]
#  4 - fs.mixer2.o2_strm_state[0.0].temperature
#  5 - fs.mixer2.o2_strm_state[0.0].pressure
#  6 - fs.mixer2.o2_poor_strm_state[0.0].flow_mol
#  7 - fs.mixer2.o2_poor_strm_state[0.0].mole_frac_comp[O2]
#  8 - fs.mixer2.o2_poor_strm_state[0.0].mole_frac_comp[N2]
#  9 - fs.mixer2.o2_poor_strm_state[0.0].temperature
#  10 - fs.mixer2.o2_poor_strm_state[0.0].pressure
#  11 - fs.mixer2.mixed_state[0.0].flow_mol
#  12 - fs.mixer2.mixed_state[0.0].mole_frac_comp[O2]
#  13 - fs.mixer2.mixed_state[0.0].mole_frac_comp[N2]
#  14 - fs.mixer2.mixed_state[0.0].temperature
#  15 - fs.mixer2.mixed_state[0.0].pressure
#  16 - fs.mixer2.o2_strm_state[0.0].flow_mol_phase[Vap]
#  17 - fs.mixer2.o2_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
#  18 - fs.mixer2.o2_strm_state[0.0].mole_frac_phase_comp[Vap,N2]
#  19 - fs.mixer2.o2_strm_state[0.0].phase_frac[Vap]
#  20 - fs.mixer2.o2_poor_strm_state[0.0].flow_mol_phase[Vap]
#  21 - fs.mixer2.o2_poor_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
#  22 - fs.mixer2.o2_poor_strm_state[0.0].mole_frac_phase_comp[Vap,N2]
#  23 - fs.mixer2.o2_poor_strm_state[0.0].phase_frac[Vap]
#  24 - fs.mixer2.mixed_state[0.0].flow_mol_phase[Vap]
#  25 - fs.mixer2.mixed_state[0.0].mole_frac_phase_comp[Vap,O2]
#  26 - fs.mixer2.mixed_state[0.0].mole_frac_phase_comp[Vap,N2]
#  27 - fs.mixer2.mixed_state[0.0].phase_frac[Vap]
#
# ------------------------------------------------------------
# FIXED VARIABLES:
# ------------------------------------------------------------
# ============================================================
